# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import random
import math

# %%
df=pd.read_csv('../data/survey_results_public.csv')

# %%
print('df has {} rows and {} columns'.format(*df.shape))
# Out:
# df has 64461 rows and 61 columns

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0   European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1  Pound sterling  ...                         NaN                    NaN
# 2             NaN  ...  Neither easy nor difficult  Appropriate in length
# 3    Albanian lek  ...                         NaN                    NaN
# 4             NaN  ...                        Easy              Too short
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 3    No  Computer science, computer engineering, or sof...
# 4    No  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4   Django;Ruby on Rails         Ruby on Rails
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 0   Just as welcome now as I felt last year        50.0        36           27
# 1  Somewhat more welcome now than last year         NaN         7            4
# 2  Somewhat more welcome now than last year         NaN         4          NaN
# 3  Somewhat less welcome now than last year        40.0         7            4
# 4   Just as welcome now as I felt last year         NaN        15            8
#
# [5 rows x 61 columns]

# %%
categoricals=[]
multi_options=[]
numericals=[]

# %%
categoricals.append('MainBranch')
# df['MainBranch'].unique()
df['MainBranch'].hist(xrot=90)

# %%
numericals.append('Age')
pd.to_numeric(df['Age'], errors='coerce').hist(bins=100, xrot=90)

# %%
numericals.append('Age1stCode')
pd.to_numeric(df['Age1stCode'], errors='coerce').hist(bins=100, xrot=90)

# %%
categoricals.append('Country')
# df['Country'].unique()
df['Country'].hist(xrot=90, figsize=(20, 5))

# %%
multi_options.append('DatabaseWorkedWith')
df['DatabaseWorkedWith'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
df['DevType'].unique()
# Out:
# array(['Developer, desktop or enterprise applications;Developer, full-stack',
#        'Developer, full-stack;Developer, mobile', nan, ...,
#        'Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, front-end;System administrator',
#        'Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;DevOps specialist;Senior executive/VP;System administrator',
#        'Data or business analyst;Developer, mobile;Senior executive/VP;System administrator'],
#       dtype=object)

# %%
multi_options.append('DevType')
df['DevType'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
categoricals.append('EdLevel')
df['EdLevel'].hist(xrot=90)

# %%
categoricals.append('Employment')
df['Employment'].hist(xrot=90)

# %%
# multi_options.append('Ethnicity')
# df['Ethnicity'].str.get_dummies(sep=';')

# %%
multi_options.append('Gender')
df['Gender'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
multi_options.append('LanguageWorkedWith')
df['LanguageWorkedWith'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
multi_options.append('MiscTechWorkedWith')
df['MiscTechWorkedWith'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
multi_options.append('NEWCollabToolsWorkedWith')
df['NEWCollabToolsWorkedWith'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
categoricals.append('OpSys')
df['OpSys'].hist(xrot=90)

# %%
multi_options.append('PlatformWorkedWith')
df['PlatformWorkedWith'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
categoricals.append('UndergradMajor')
df['UndergradMajor'].hist(xrot=90)

# %%
multi_options.append('WebframeWorkedWith')
df['WebframeWorkedWith'].str.get_dummies(sep=';').sum().plot(kind='bar', rot=90)

# %%
numericals.append('YearsCode')
pd.to_numeric(df['YearsCode'], errors='coerce').hist(bins=100, xrot=90)

# %%
numericals.append('YearsCodePro')
# df['YearsCodeProNEW']=pd.to_numeric(df['YearsCodePro'], errors='coerce').map(lambda x: min(x, 10))
pd.to_numeric(df['YearsCodePro'], errors='coerce').hist(bins=100, xrot=90)

# %%
multi_options
# Out:
# ['DatabaseWorkedWith',
#  'DevType',
#  'Gender',
#  'LanguageWorkedWith',
#  'MiscTechWorkedWith',
#  'NEWCollabToolsWorkedWith',
#  'PlatformWorkedWith',
#  'WebframeWorkedWith']

# %%
numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
# numericals=['YearsCodePro']
categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
# categoricals=['EdLevel']
multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
# multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']

# %%
# X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=10000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
X=df[['ConvertedComp']]
for each_col in numericals:
    X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
for each_col in categoricals: 
    X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
for each_col in multi_options: 
    X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)
X.to_csv('model_inputs.csv')

# %%
numericals
# Out:
# ['Age',
#  'Age1stCode',
#  'YearsCode',
#  'YearsCodePro',
#  'Age',
#  'Age',
#  'Age',
#  'Age1stCode',
#  'Age',
#  'Age1stCode',
#  'YearsCode',
#  'YearsCodePro']

# %%
import seaborn as sns
sns.heatmap(X[numericals+['ConvertedComp']].corr(), annot=True)

# %%
X.columns
# Out:
# Index(['ConvertedComp', 'Age', 'Age1stCode', 'YearsCode', 'YearsCodePro',
#        'I am a developer by profession',
#        'I am a student who is learning to code',
#        'I am not primarily a developer, but I write code sometimes as part of my work',
#        'I code primarily as a hobby',
#        'I used to be a developer by profession, but no longer am',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=352)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def run_model(X, all_numericals, all_categoricals, all_multi_options): 
    print(f'{X.shape} before trim')
    X=X[all_numericals+all_categoricals+all_multi_options+['ConvertedComp']]
    input_ary=X.dropna().drop('ConvertedComp', axis=1)
    y=X.dropna()['ConvertedComp']
    for each_col in all_numericals: 
        X[['ConvertedComp', each_col]].boxplot(by=each_col, showfliers=False, rot=90, figsize=(20, 10))
    sns.heatmap(X.dropna().corr(), annot=True)
    print(f'{X.shape} after trim')
    X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
    rfr=RandomForestRegressor()
    rfr.fit(X_train, y_train)
    print(f'RFR Train Score: {rfr.score(X_train, y_train)}')
    print(f'RFR Test Score: {rfr.score(X_test, y_test)}')
    lr=LinearRegression()
    lr.fit(X_train, y_train)
    print(f'LR Train Score: {lr.score(X_train, y_train)}')
    print(f'LR Test Score: {lr.score(X_test, y_test)}')

# %% [markdown]
# # Testing

# %%
us=X[(X['United States']==1) & 
     (X['Employed full-time']==1) &
     (X['ConvertedComp']<=200000) & 
     (X['ConvertedComp']>=40000)]
run_model(us, ['YearsCodePro'], 
          ['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
           'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
           'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
           'Professional degree (JD, MD, etc.)',
           'Some college/university study without earning a degree',
           'Associate degree (A.A., A.S., etc.)',
           'Other doctoral degree (Ph.D., Ed.D., etc.)',
           'Primary/elementary school',
           'I never completed any formal education'], 
          ['Academic researcher', 'Data or business analyst',
           'Data scientist or machine learning specialist',
           'Database administrator', 'Designer', 'DevOps specialist',
           'Developer, QA or test', 'Developer, back-end',
           'Developer, desktop or enterprise applications',
           'Developer, embedded applications or devices', 'Developer, front-end',
           'Developer, full-stack', 'Developer, game or graphics',
           'Developer, mobile', 'Educator', 'Engineer, data',
           'Engineer, site reliability', 'Engineering manager',
           'Marketing or sales professional', 'Product manager', 'Scientist',
           'Senior executive/VP', 'System administrator'])
# Out:
# (6456, 352) before trim
# (6456, 34) after trim
# RFR Train Score: 0.683661214407478
# RFR Test Score: 0.14728458803831834
# LR Train Score: 0.2484262681974354
# LR Test Score: 0.26502724187311555
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
us=X[(X['United States']==1) & 
     (X['Employed full-time']==1) &
     (X['ConvertedComp']<=200000) & 
     (X['ConvertedComp']>=40000) & 
     (X['Data scientist or machine learning specialist']==1)]
run_model(us, ['YearsCodePro'], 
          ['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
           'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
           'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
           'Professional degree (JD, MD, etc.)',
           'Some college/university study without earning a degree',
           'Associate degree (A.A., A.S., etc.)',
           'Other doctoral degree (Ph.D., Ed.D., etc.)',
           'Primary/elementary school',
           'I never completed any formal education'], 
          ['Academic researcher', 'Data or business analyst',
           'Data scientist or machine learning specialist',
           'Database administrator', 'Designer', 'DevOps specialist',
           'Developer, QA or test', 'Developer, back-end',
           'Developer, desktop or enterprise applications',
           'Developer, embedded applications or devices', 'Developer, front-end',
           'Developer, full-stack', 'Developer, game or graphics',
           'Developer, mobile', 'Educator', 'Engineer, data',
           'Engineer, site reliability', 'Engineering manager',
           'Marketing or sales professional', 'Product manager', 'Scientist',
           'Senior executive/VP', 'System administrator'])
# Out:
# (460, 352) before trim
# (460, 34) after trim
# RFR Train Score: 0.8043186742144954
# RFR Test Score: -0.026844763314820108
# LR Train Score: 0.3397003992048825
# LR Test Score: 0.22770378560788254
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
us=X[(X['United States']==1) & 
     (X['Employed full-time']==1) &
     (X['ConvertedComp']<=200000) &
     (X['ConvertedComp']>=40000) &
     ((X['Data scientist or machine learning specialist']==1) | 
     (X['Data or business analyst']==1))]
run_model(us, ['YearsCodePro'], 
          ['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
           'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
           'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
           'Professional degree (JD, MD, etc.)',
           'Some college/university study without earning a degree',
           'Associate degree (A.A., A.S., etc.)',
           'Other doctoral degree (Ph.D., Ed.D., etc.)',
           'Primary/elementary school',
           'I never completed any formal education'], 
          ['Data scientist or machine learning specialist'])
# Out:
# (879, 352) before trim
# (879, 12) after trim
# RFR Train Score: 0.43589246422666106
# RFR Test Score: 0.08518292824047946
# LR Train Score: 0.21111014808151263
# LR Test Score: 0.22023128185205076
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
us=X[(X['United States']==1) & 
     (X['Employed full-time']==1) &
     (X['ConvertedComp']<=200000) & 
     (X['ConvertedComp']>=40000)]
run_model(us, ['YearsCode'], 
          ['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
           'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
           'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
           'Professional degree (JD, MD, etc.)',
           'Some college/university study without earning a degree',
           'Associate degree (A.A., A.S., etc.)',
           'Other doctoral degree (Ph.D., Ed.D., etc.)',
           'Primary/elementary school',
           'I never completed any formal education'], 
          ['Academic researcher', 'Data or business analyst',
           'Data scientist or machine learning specialist',
           'Database administrator', 'Designer', 'DevOps specialist',
           'Developer, QA or test', 'Developer, back-end',
           'Developer, desktop or enterprise applications',
           'Developer, embedded applications or devices', 'Developer, front-end',
           'Developer, full-stack', 'Developer, game or graphics',
           'Developer, mobile', 'Educator', 'Engineer, data',
           'Engineer, site reliability', 'Engineering manager',
           'Marketing or sales professional', 'Product manager', 'Scientist',
           'Senior executive/VP', 'System administrator'])
# Out:
# (6456, 352) before trim
# (6456, 34) after trim
# RFR Train Score: 0.6996942621530132
# RFR Test Score: 0.09439868706517052
# LR Train Score: 0.2463359088018966
# LR Test Score: 0.2330257557531069
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
us=X[(X['United States']==1) & 
     (X['Employed full-time']==1) &
     (X['ConvertedComp']<=200000) & 
     (X['ConvertedComp']>=40000)]
# run_model(us, ['Age'], 
#           ['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#            'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#            'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#            'Professional degree (JD, MD, etc.)',
#            'Some college/university study without earning a degree',
#            'Associate degree (A.A., A.S., etc.)',
#            'Other doctoral degree (Ph.D., Ed.D., etc.)',
#            'Primary/elementary school',
#            'I never completed any formal education'], 
#           ['Academic researcher', 'Data or business analyst',
#            'Data scientist or machine learning specialist',
#            'Database administrator', 'Designer', 'DevOps specialist',
#            'Developer, QA or test', 'Developer, back-end',
#            'Developer, desktop or enterprise applications',
#            'Developer, embedded applications or devices', 'Developer, front-end',
#            'Developer, full-stack', 'Developer, game or graphics',
#            'Developer, mobile', 'Educator', 'Engineer, data',
#            'Engineer, site reliability', 'Engineering manager',
#            'Marketing or sales professional', 'Product manager', 'Scientist',
#            'Senior executive/VP', 'System administrator'])
us['Job']=us[['Academic researcher', 'Data or business analyst',
           'Data scientist or machine learning specialist',
           'Database administrator', 'Designer', 'DevOps specialist',
           'Developer, QA or test', 'Developer, back-end',
           'Developer, desktop or enterprise applications',
           'Developer, embedded applications or devices', 'Developer, front-end',
           'Developer, full-stack', 'Developer, game or graphics',
           'Developer, mobile', 'Educator', 'Engineer, data',
           'Engineer, site reliability', 'Engineering manager',
           'Marketing or sales professional', 'Product manager', 'Scientist',
           'Senior executive/VP', 'System administrator']].idxmax(axis=1)
us[['Job', 'ConvertedComp']].boxplot(by='Job', showfliers=False, rot=90)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
titles=['Academic researcher', 'Data or business analyst',
       'Data scientist or machine learning specialist',
       'Database administrator', 'Designer', 'DevOps specialist',
       'Developer, QA or test', 'Developer, back-end',
       'Developer, desktop or enterprise applications',
       'Developer, embedded applications or devices', 'Developer, front-end',
       'Developer, full-stack', 'Developer, game or graphics',
       'Developer, mobile', 'Educator', 'Engineer, data',
       'Engineer, site reliability', 'Engineering manager',
       'Marketing or sales professional', 'Product manager', 'Scientist',
       'Senior executive/VP', 'System administrator']
columns=5
fig, ax=plt.subplots(math.ceil(len(titles)/columns), columns, figsize=(20, 20), sharey=True)
for idx, each_title in enumerate(titles):
    us[us[each_title]==1][['ConvertedComp']].boxplot(showfliers=False, ax=ax[int(idx/columns)][idx%columns])
    ax[int(idx/columns)][idx%columns].set_title(each_title)
#     plt.show()

# %% [markdown]
# # Testing

# %% [markdown]
# ['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
#
# ['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
#
# ['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']

# %%
# print(numericals)
numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
# numericals=['YearsCodePro']
# print(categoricals)
categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
# categoricals=['EdLevel']
# print(multi_options)
multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
# multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def test_features(numericals, categoricals, multi_options):    
    X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=10000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
    X=X[X['Country']=='United States'][['ConvertedComp']]
#     X=X[['ConvertedComp']]
    for each_col in numericals:
        X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
    for each_col in categoricals: 
        X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
    for each_col in multi_options: 
        X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)    
    input_ary=X.dropna().drop('ConvertedComp', axis=1)
    y=X.dropna()['ConvertedComp']
    print(input_ary.shape)
    print(sorted(input_ary.columns))
    X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
    rfr=RandomForestRegressor()
    rfr.fit(X_train, y_train)
    print(f'LR Train Score: {rfr.score(X_train, y_train)}')
    print(f'LR Test Score: {rfr.score(X_test, y_test)}')
    lr=LinearRegression()
    # input_ary=X.dropna()[['YearsCodePro']]
    # y=X.dropna()['ConvertedComp']
#     X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
    lr.fit(input_ary, y)
    lr.score(input_ary, y)
    print(f'LR Train Score: {lr.score(X_train, y_train)}')
    print(f'LR Test Score: {lr.score(X_test, y_test)}')

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=['YearsCodePro']
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=['EdLevel']
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
test_features(numericals, categoricals, multi_options)
# Out:
# (25379, 134)
# ['.NET', '.NET Core', 'ASP.NET', 'ASP.NET Core', 'AWS', 'Academic researcher', 'Android', 'Angular', 'Angular.js', 'Ansible', 'Apache Spark', 'Arduino', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bash/Shell/PowerShell', 'C', 'C#', 'C++', 'Cassandra', 'Chef', 'Confluence', 'Cordova', 'Couchbase', 'Dart', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Django', 'Docker', 'Drupal', 'DynamoDB', 'Educator', 'Elasticsearch', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Express', 'Facebook Workplace', 'Firebase', 'Flask', 'Flutter', 'Gatsby', 'Github', 'Gitlab', 'Go', 'Google Cloud Platform', 'Google Suite (Docs, Meet, etc)', 'HTML/CSS', 'Hadoop', 'Haskell', 'Heroku', 'I never completed any formal education', 'IBM Cloud or Watson', 'IBM DB2', 'Java', 'JavaScript', 'Jira', 'Julia', 'Keras', 'Kotlin', 'Kubernetes', 'Laravel', 'Linux', 'MacOS', 'MariaDB', 'Marketing or sales professional', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Microsoft Azure', 'Microsoft Azure', 'Microsoft SQL Server', 'Microsoft Teams', 'MongoDB', 'MySQL', 'Node.js', 'Objective-C', 'Oracle', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'PHP', 'Pandas', 'Perl', 'PostgreSQL', 'Primary/elementary school', 'Product manager', 'Professional degree (JD, MD, etc.)', 'Puppet', 'Python', 'R', 'Raspberry Pi', 'React Native', 'React.js', 'Redis', 'Ruby', 'Ruby on Rails', 'Rust', 'SQL', 'SQLite', 'Scala', 'Scientist', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senior executive/VP', 'Slack', 'Slack Apps and Integrations', 'Some college/university study without earning a degree', 'Spring', 'Stack Overflow for Teams', 'Swift', 'Symfony', 'System administrator', 'TensorFlow', 'Teraform', 'Torch/PyTorch', 'Trello', 'TypeScript', 'Unity 3D', 'Unreal Engine', 'VBA', 'Vue.js', 'Windows', 'WordPress', 'Xamarin', 'YearsCodePro', 'iOS', 'jQuery']
# LR Train Score: 0.8740450151914314
# LR Test Score: 0.11452722261205639
# LR Train Score: 0.1904317348968637
# LR Test Score: 0.18048867179349237

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=['YearsCodePro']
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=['EdLevel', 'UndergradMajor', 'Country']
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
for each_col in multi_options: 
    test_features(numericals, categoricals, [each_col])
# Out:
# (25379, 219)
# ['A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cassandra', 'Chad', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Congo, Republic of the...', 'Costa Rica', 'Couchbase', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'DynamoDB', 'Ecuador', 'Egypt', 'El Salvador', 'Elasticsearch', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'Firebase', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'IBM DB2', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'MariaDB', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft SQL Server', 'Monaco', 'MongoDB', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'MySQL', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Oracle', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'PostgreSQL', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Redis', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'SQLite', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Web development or web design', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.8454727096469881
# LR Test Score: 0.21341563813144715
# LR Train Score: 0.39687963269396853
# LR Test Score: 0.3370929699708106
# (25379, 228)
# ['A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'Academic researcher', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Democratic Republic of the Congo', 'Denmark', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Educator', 'Egypt', 'El Salvador', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marketing or sales professional', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Product manager', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Scientist', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Senior executive/VP', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'System administrator', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Tu ...
# LR Train Score: 0.8552480623533855
# LR Test Score: 0.2564226189448231
# LR Train Score: 0.40176107414722406
# LR Test Score: 0.34319941724072656
# (25379, 230)
# ['A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Bash/Shell/PowerShell', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'C', 'C#', 'C++', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Dart', 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Go', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'HTML/CSS', 'Haiti', 'Haskell', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Java', 'JavaScript', 'Jordan', 'Julia', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kotlin', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Objective-C', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'PHP', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Perl', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Python', 'Qatar', 'R', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Ruby', 'Russian Federation', 'Rust', 'Rwanda', 'SQL', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Scala', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Swift', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'TypeScript', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'VBA', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Web development or web design', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.8914086662761849
# LR Test Score: 0.28294879740869894
# LR Train Score: 0.39114603476255405
# LR Test Score: 0.3760003238050761
# (25379, 224)
# ['.NET', '.NET Core', 'A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Ansible', 'Antigua and Barbuda', 'Apache Spark', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chef', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Congo, Republic of the...', 'Cordova', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'Flutter', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Hadoop', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Keras', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Node.js', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Pandas', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Puppet', 'Qatar', 'React Native', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'TensorFlow', 'Teraform', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Torch/PyTorch', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Unity 3D', 'Unreal Engine', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Web development or web design', 'Xamarin', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.785181185019236
# LR Test Score: 0.24050815019128147
# LR Train Score: 0.3849510948341007
# LR Test Score: 0.3553087519786987
# (25379, 216)
# ['A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Confluence', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Facebook Workplace', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Github', 'Gitlab', 'Google Suite (Docs, Meet, etc)', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jira', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft Azure', 'Microsoft Teams', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slack', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Stack Overflow for Teams', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trello', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Web development or web design', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.8635306224830387
# LR Test Score: 0.25733641457824585
# LR Train Score: 0.37162390758738917
# LR Test Score: 0.39607119772291943
# (25379, 221)
# ['A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'AWS', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Android', 'Angola', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Antigua and Barbuda', 'Arduino', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Docker', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Google Cloud Platform', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Heroku', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'IBM Cloud or Watson', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kubernetes', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Linux', 'Lithuania', 'Luxembourg', 'MacOS', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft Azure', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Raspberry Pi', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slack Apps and Integrations', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Web development or web design', 'Windows', 'WordPress', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe', 'iOS']
# LR Train Score: 0.8615189382167505
# LR Test Score: 0.25180043646737904
# LR Train Score: 0.3791841298864941
# LR Test Score: 0.39893603705608216
# (25379, 221)
# ['A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'ASP.NET', 'ASP.NET Core', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Angular', 'Angular.js', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Django', 'Djibouti', 'Dominican Republic', 'Drupal', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Express', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'Flask', 'France', 'Gabon', 'Gambia', 'Gatsby', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'I never declared a major', 'Iceland', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Laravel', 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'React.js', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Ruby on Rails', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Spring', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Symfony', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Vue.js', 'Web development or web design', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe', 'jQuery']
# LR Train Score: 0.8182870832265428
# LR Test Score: 0.22345093375442648
# LR Train Score: 0.3772420451517663
# LR Test Score: 0.37772313365612364

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=['YearsCodePro']
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=['EdLevel', 'Country']
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
for each_col in multi_options: 
    test_features(numericals, categoricals, [each_col])
# Out:
# (25379, 207)
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cassandra', 'Chad', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Costa Rica', 'Couchbase', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'DynamoDB', 'Ecuador', 'Egypt', 'El Salvador', 'Elasticsearch', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'Firebase', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'IBM DB2', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'MariaDB', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft SQL Server', 'Monaco', 'MongoDB', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'MySQL', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Oracle', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'PostgreSQL', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Redis', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'SQLite', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.7953741031550716
# LR Test Score: 0.24373983953747458
# LR Train Score: 0.3744726648155081
# LR Test Score: 0.3953261396790667
# (25379, 216)
# ['Academic researcher', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Democratic Republic of the Congo', 'Denmark', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Educator', 'Egypt', 'El Salvador', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marketing or sales professional', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Product manager', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Scientist', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Senior executive/VP', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'System administrator', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.8058627890413237
# LR Test Score: 0.2636443628218541
# LR Train Score: 0.3880793673480357
# LR Test Score: 0.3774757860594503
# (25379, 218)
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Bash/Shell/PowerShell', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'C', 'C#', 'C++', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Dart', 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Go', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'HTML/CSS', 'Haiti', 'Haskell', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Java', 'JavaScript', 'Jordan', 'Julia', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kotlin', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Objective-C', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'PHP', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Perl', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Python', 'Qatar', 'R', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Ruby', 'Russian Federation', 'Rust', 'Rwanda', 'SQL', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Scala', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Swift', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'TypeScript', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'VBA', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.877873326875119
# LR Test Score: 0.25850977071558234
# LR Train Score: 0.39159844214032746
# LR Test Score: 0.37146398234108413
# (25379, 212)
# ['.NET', '.NET Core', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Ansible', 'Antigua and Barbuda', 'Apache Spark', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chef', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Cordova', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'Flutter', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Hadoop', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Keras', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Node.js', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Pandas', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Puppet', 'Qatar', 'React Native', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'TensorFlow', 'Teraform', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Torch/PyTorch', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Unity 3D', 'Unreal Engine', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Xamarin', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.7183210325760974
# LR Test Score: 0.24723693506137168
# LR Train Score: 0.37175606071691025
# LR Test Score: 0.38983083484313186
# (25379, 204)
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Confluence', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Facebook Workplace', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Github', 'Gitlab', 'Google Suite (Docs, Meet, etc)', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jira', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft Azure', 'Microsoft Teams', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slack', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Stack Overflow for Teams', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trello', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe']
# LR Train Score: 0.8301830438656785
# LR Test Score: 0.26829322759653595
# LR Train Score: 0.36710802997114655
# LR Test Score: 0.4034273642728625
# (25379, 209)
# ['AWS', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Android', 'Angola', 'Antigua and Barbuda', 'Arduino', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Docker', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Google Cloud Platform', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Heroku', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'IBM Cloud or Watson', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kubernetes', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Linux', 'Lithuania', 'Luxembourg', 'MacOS', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft Azure', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'Raspberry Pi', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slack Apps and Integrations', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Windows', 'WordPress', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe', 'iOS']
# LR Train Score: 0.8307627532962123
# LR Test Score: 0.23330059679112125
# LR Train Score: 0.38914670734710655
# LR Test Score: 0.3642785716767164
# (25379, 209)
# ['ASP.NET', 'ASP.NET Core', 'Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Angular', 'Angular.js', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chad', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Democratic Republic of the Congo', 'Denmark', 'Django', 'Djibouti', 'Dominican Republic', 'Drupal', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Express', 'Fiji', 'Finland', 'Flask', 'France', 'Gabon', 'Gambia', 'Gatsby', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I never completed any formal education', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Laravel', 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Nomadic', 'North Korea', 'Norway', 'Oman', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Pakistan', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Primary/elementary school', 'Professional degree (JD, MD, etc.)', 'Qatar', 'React.js', 'Republic of Korea', 'Republic of Moldova', 'Romania', 'Ruby on Rails', 'Russian Federation', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'Some college/university study without earning a degree', 'South Africa', 'South Korea', 'Spain', 'Spring', 'Sri Lanka', 'Sudan', 'Swaziland', 'Sweden', 'Switzerland', 'Symfony', 'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Thailand', 'The former Yugoslav Republic of Macedonia', 'Timor-Leste', 'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Republic of Tanzania', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...', 'Viet Nam', 'Vue.js', 'YearsCodePro', 'Yemen', 'Zambia', 'Zimbabwe', 'jQuery']
# LR Train Score: 0.7618972667691141
# LR Test Score: 0.2640784145431563
# LR Train Score: 0.3761842780784962
# LR Test Score: 0.37603906664278486

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=[]
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=[]
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
for each_col in multi_options: 
    test_features(numericals, categoricals, [each_col])
# Out:
# (7140, 14)
# ['Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch', 'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB', 'MySQL', 'Oracle', 'PostgreSQL', 'Redis', 'SQLite']
# LR Train Score: 0.17783376036704712
# LR Test Score: 0.01794063641518906
# LR Train Score: 0.05421047284576008
# LR Test Score: 0.06818890769451413
# (7140, 23)
# ['Academic researcher', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Educator', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Marketing or sales professional', 'Product manager', 'Scientist', 'Senior executive/VP', 'System administrator']
# LR Train Score: 0.33117247009823414
# LR Test Score: -0.006352032316092382
# LR Train Score: 0.09681694332537394
# LR Test Score: 0.10409813113664868
# (7140, 25)
# ['Assembly', 'Bash/Shell/PowerShell', 'C', 'C#', 'C++', 'Dart', 'Go', 'HTML/CSS', 'Haskell', 'Java', 'JavaScript', 'Julia', 'Kotlin', 'Objective-C', 'PHP', 'Perl', 'Python', 'R', 'Ruby', 'Rust', 'SQL', 'Scala', 'Swift', 'TypeScript', 'VBA']
# LR Train Score: 0.5248971024682882
# LR Test Score: 0.0008297034188580188
# LR Train Score: 0.09781729439273879
# LR Test Score: 0.10909161501471865
# (7140, 19)
# ['.NET', '.NET Core', 'Ansible', 'Apache Spark', 'Chef', 'Cordova', 'Flutter', 'Hadoop', 'Keras', 'Node.js', 'Pandas', 'Puppet', 'React Native', 'TensorFlow', 'Teraform', 'Torch/PyTorch', 'Unity 3D', 'Unreal Engine', 'Xamarin']
# LR Train Score: 0.1574512706819674
# LR Test Score: -0.031212285766351267
# LR Train Score: 0.04279196083614001
# LR Test Score: 0.03111920788234601
# (7140, 11)
# ['Confluence', 'Facebook Workplace', 'Github', 'Gitlab', 'Google Suite (Docs, Meet, etc)', 'Jira', 'Microsoft Azure', 'Microsoft Teams', 'Slack', 'Stack Overflow for Teams', 'Trello']
# LR Train Score: 0.15398656833048763
# LR Test Score: 0.008977150870389972
# LR Train Score: 0.05289587668606088
# LR Test Score: 0.02952770149978534
# (7140, 16)
# ['AWS', 'Android', 'Arduino', 'Docker', 'Google Cloud Platform', 'Heroku', 'IBM Cloud or Watson', 'Kubernetes', 'Linux', 'MacOS', 'Microsoft Azure', 'Raspberry Pi', 'Slack Apps and Integrations', 'Windows', 'WordPress', 'iOS']
# LR Train Score: 0.3172982112475665
# LR Test Score: -0.054479884033521
# LR Train Score: 0.07668235853368488
# LR Test Score: 0.06306193612655964
# (7140, 16)
# ['ASP.NET', 'ASP.NET Core', 'Angular', 'Angular.js', 'Django', 'Drupal', 'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails', 'Spring', 'Symfony', 'Vue.js', 'jQuery']
# LR Train Score: 0.13921931348570415
# LR Test Score: -0.04498016082970957
# LR Train Score: 0.03468541022826954
# LR Test Score: 0.03880431377127336

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=[]
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=[]
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
for each_col in multi_options: 
    test_features(numericals, categoricals, [each_col])
# Out:
# (7140, 14)
# ['Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch', 'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB', 'MySQL', 'Oracle', 'PostgreSQL', 'Redis', 'SQLite']
# LR Train Score: 0.19512264536753088
# LR Test Score: -0.001377948881380986
# LR Train Score: 0.05573346633126608
# LR Test Score: 0.06390297238109788
# (7140, 23)
# ['Academic researcher', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Educator', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Marketing or sales professional', 'Product manager', 'Scientist', 'Senior executive/VP', 'System administrator']
# LR Train Score: 0.3191023443884027
# LR Test Score: 0.02632305989735917
# LR Train Score: 0.09939619130359512
# LR Test Score: 0.09552232060510701
# (7140, 25)
# ['Assembly', 'Bash/Shell/PowerShell', 'C', 'C#', 'C++', 'Dart', 'Go', 'HTML/CSS', 'Haskell', 'Java', 'JavaScript', 'Julia', 'Kotlin', 'Objective-C', 'PHP', 'Perl', 'Python', 'R', 'Ruby', 'Rust', 'SQL', 'Scala', 'Swift', 'TypeScript', 'VBA']
# LR Train Score: 0.5260868303962345
# LR Test Score: -0.022948196181422853
# LR Train Score: 0.09488021733676866
# LR Test Score: 0.11721631351693218
# (7140, 19)
# ['.NET', '.NET Core', 'Ansible', 'Apache Spark', 'Chef', 'Cordova', 'Flutter', 'Hadoop', 'Keras', 'Node.js', 'Pandas', 'Puppet', 'React Native', 'TensorFlow', 'Teraform', 'Torch/PyTorch', 'Unity 3D', 'Unreal Engine', 'Xamarin']
# LR Train Score: 0.15122776625651968
# LR Test Score: -0.019371767549011487
# LR Train Score: 0.039637333322664725
# LR Test Score: 0.03991508100565966
# (7140, 11)
# ['Confluence', 'Facebook Workplace', 'Github', 'Gitlab', 'Google Suite (Docs, Meet, etc)', 'Jira', 'Microsoft Azure', 'Microsoft Teams', 'Slack', 'Stack Overflow for Teams', 'Trello']
# LR Train Score: 0.14223800116898133
# LR Test Score: 0.033842077696283224
# LR Train Score: 0.045167458736938504
# LR Test Score: 0.05255817175654909
# (7140, 16)
# ['AWS', 'Android', 'Arduino', 'Docker', 'Google Cloud Platform', 'Heroku', 'IBM Cloud or Watson', 'Kubernetes', 'Linux', 'MacOS', 'Microsoft Azure', 'Raspberry Pi', 'Slack Apps and Integrations', 'Windows', 'WordPress', 'iOS']
# LR Train Score: 0.3193215243508887
# LR Test Score: -0.05836667350309077
# LR Train Score: 0.0742700841894921
# LR Test Score: 0.07006578572122102
# (7140, 16)
# ['ASP.NET', 'ASP.NET Core', 'Angular', 'Angular.js', 'Django', 'Drupal', 'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails', 'Spring', 'Symfony', 'Vue.js', 'jQuery']
# LR Train Score: 0.13852437619008673
# LR Test Score: -0.021064447620398496
# LR Train Score: 0.03305117034090532
# LR Test Score: 0.043511951834035

# %%
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=10000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
X=X[X['Country']=='United States'][['ConvertedComp']]
for each_col in multi_options: 
    X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1) 
tech
for column in multi_options: 
    print(column)
    print(X.columns)
    input_ary=X.dropna().drop('ConvertedComp', axis=1)
    print(input_ary)
# Out:
# DatabaseWorkedWith
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]
# DevType
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]
# LanguageWorkedWith
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]
# MiscTechWorkedWith
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]
# NEWCollabToolsWorkedWith
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]
# PlatformWorkedWith
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]
# WebframeWorkedWith
# Index(['ConvertedComp', 'Cassandra', 'Couchbase', 'DynamoDB', 'Elasticsearch',
#        'Firebase', 'IBM DB2', 'MariaDB', 'Microsoft SQL Server', 'MongoDB',
#        ...
#        'Express', 'Flask', 'Gatsby', 'Laravel', 'React.js', 'Ruby on Rails',
#        'Spring', 'Symfony', 'Vue.js', 'jQuery'],
#       dtype='object', length=125)
#        Cassandra  Couchbase  DynamoDB  Elasticsearch  Firebase  IBM DB2  \
# 7              0          0         0              0         0        0
# 13             0          0         0              0         1        0
# 16             0          0         0              0         0        0
# 18             0          0         0              0         0        0
# 40             0          0         0              0         0        0
# ...          ...        ...       ...            ...       ...      ...
# 64113          0          0         0              0         0        0
# 64116          0          0         0              0         0        0
# 64122          0          0         0              0         1        0
# 64127          0          0         0              0         0        0
# 64129          0          0         0              0         0        0
#
#        MariaDB  Microsoft SQL Server  MongoDB  MySQL  ...  Express  Flask  \
# 7            1                     0        0      1  ...        0      1
# 13           0                     1        0      0  ...        0      0
# 16           0                     1        0      0  ...        0      0
# 18           1                     1        0      0  ...        0      0
# 40           0                     1        0      0  ...        0      0
# ...        ...                   ...      ...    ...  ...      ...    ...
# 64113        0                     0        0      0  ...        0      0
# 64116        0                     0        0      0  ...        0      0
# 64122        0                     0        1      1  ...        0      0
# 64127        0                     0        0      0  ...        0      0
# 64129        0                     0        0      0  ...        0      0
#
#        Gatsby  Laravel  React.js  Ruby on Rails  Spring  Symfony  Vue.js  \
# 7           0        0         0              0       0        0       0
# 13          0        0         0              0       0        0       1
# 16          1        0         1              0       0        0       1
# 18          0        0         0              0       0        0       0
# 40          0        0         0              0       0        0       1
# ...       ...      ...       ...            ...     ...      ...     ...
# 64113       0        0         0              0       0        0       0
# 64116       0        0         0              0       0        0       0
# 64122       0        0         1              1       0        0       0
# 64127       0        0         0              0       0        0       0
# 64129       0        0         0              0       0        0       0
#
#        jQuery
# 7           0
# 13          0
# 16          1
# 18          0
# 40          0
# ...       ...
# 64113       0
# 64116       0
# 64122       1
# 64127       0
# 64129       0
#
# [7140 rows x 124 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def test_features(numericals, categoricals, multi_options):    
    X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=10000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
    X=X[X['Country']=='United States'][['ConvertedComp']]
#     X=X[['ConvertedComp']]
    for each_col in numericals:
        X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
    for each_col in categoricals: 
        X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
    for each_col in multi_options: 
        X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)    
    input_ary=X.dropna().drop('ConvertedComp', axis=1)
    y=X.dropna()['ConvertedComp']
    tech_list=input_ary.columns
    
    for each_col in tech_list: 
        print(input_ary.shape)
#         print(sorted(input_ary.columns))
        print(each_col)
        small_ary=input_ary[[each_col]]
        X_train, X_test, y_train, y_test=train_test_split(small_ary, y)
        rfr=RandomForestRegressor()
        rfr.fit(X_train, y_train)
        print(f'LR Train Score: {rfr.score(X_train, y_train)}')
        print(f'LR Test Score: {rfr.score(X_test, y_test)}')
#         lr=LinearRegression()
#         # input_ary=X.dropna()[['YearsCodePro']]
#         # y=X.dropna()['ConvertedComp']
#     #     X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
#         lr.fit(input_ary, y)
#         lr.score(input_ary, y)
#         print(f'LR Train Score: {lr.score(X_train, y_train)}')
#         print(f'LR Test Score: {lr.score(X_test, y_test)}')

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=['YearsCodePro']
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=['EdLevel', 'UndergradMajor']
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
# for each_col in multi_options: 
#     test_features(numericals, categoricals, [each_col])
test_features(numericals, categoricals, multi_options)
# Out:
# (6869, 146)
# YearsCodePro
# LR Train Score: 0.1423246436192679
# LR Test Score: 0.14760397375152745
# (6869, 146)
# Associate degree (A.A., A.S., etc.)
# LR Train Score: 0.00821328147893663
# LR Test Score: 0.006080160029801163
# (6869, 146)
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LR Train Score: 0.006057171767031133
# LR Test Score: 0.0014910226341928734
# (6869, 146)
# I never completed any formal education
# LR Train Score: 1.7066810441557223e-06
# LR Test Score: -0.002100475231430865
# (6869, 146)
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# LR Train Score: 0.011558655839948417
# LR Test Score: 0.009721557001967085
# (6869, 146)
# Other doctoral degree (Ph.D., Ed.D., etc.)
# LR Train Score: 0.006998791031865292
# LR Test Score: 0.002737961494198249
# (6869, 146)
# Primary/elementary school
# LR Train Score: 4.074055730785009e-05
# LR Test Score: -0.0026636929938508302
# (6869, 146)
# Professional degree (JD, MD, etc.)
# LR Train Score: 0.0009163820864992456
# LR Test Score: -0.002240077877888158
# (6869, 146)
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
# LR Train Score: 0.0010389770847498703
# LR Test Score: 0.0002674970033186286
# (6869, 146)
# Some college/university study without earning a degree
# LR Train Score: 0.0002431235369075857
# LR Test Score: -0.0009408805032378176
# (6869, 146)
# A business discipline (such as accounting, finance, marketing, etc.)
# LR Train Score: 0.0004664143473435134
# LR Test Score: 0.0008080680583686384
# (6869, 146)
# A health science (such as nursing, pharmacy, radiology, etc.)
# LR Train Score: 4.3056946982034106e-05
# LR Test Score: -0.0025459488091976734
# (6869, 146)
# A humanities discipline (such as literature, history, philosophy, etc.)
# LR Train Score: 0.00035327974132359774
# LR Test Score: -0.0010960177288097395
# (6869, 146)
# A natural science (such as biology, chemistry, physics, etc.)
# LR Train Score: 0.00015625088140003296
# LR Test Score: -0.0007142438529903483
# (6869, 146)
# A social science (such as anthropology, psychology, political science, etc.)
# LR Train Score: 0.0015721348688839676
# LR Test Score: -0.001637866102814689
# (6869, 146)
# Another engineering discipline (such as civil, electrical, mechanical, etc.)
# LR Train Score: 0.00045023447886871626
# LR Test Score: 0.0003884642021673157
# (6869, 146)
# Computer science, computer engineering, or software engineering
# LR Train Score: 0.006084227568297962
# LR Test Score: -0.00021491323339417612
# (6869, 146)
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)
# LR Train Score: 0.0008414749201935967
# LR Test Score: -0.0005119995723394943
# (6869, 146)
# I never declared a major
# LR Train Score: 0.0004908885230928695
# LR Test Score: -0.0026702519520174217
# (6869, 146)
# Information systems, information technology, or system administration
# LR Train Score: 0.001708753217092629
# LR Test Score: 0.0004955450801487071
# (6869, 146)
# Mathematics or statistics
# LR Train Score: 0.0004458076202366046
# LR Test Score: 0.0005607924840469458
# (6869, 146)
# Web development or web design
# LR Train Score: 0.002907753084785525
# LR Test Score: 0.007258898789491819
# (6869, 146)
# Cassandra
# LR Train Score: 0.012837941504342254
# LR Test Score: 0.006649487224696271
# (6869, 146)
# Couchbase
# LR Train Score: 0.0011870197327376042
# LR Test Score: 0.0017270746278913451
# (6869, 146)
# DynamoDB
# LR Train Score: 0.017465770654837343
# LR Test Score: -0.0050620473149478595
# (6869, 146)
# Elasticsearch
# LR Train Score: 0.006849984246980689
# LR Test Score: 0.006550403505483637
# (6869, 146)
# Firebase
# LR Train Score: 6.92500047849709e-06
# LR Test Score: -0.000829472681117549
# (6869, 146)
# IBM DB2
# LR Train Score: 0.001867106384728645
# LR Test Score: 0.0009192686155740093
# (6869, 146)
# MariaDB
# LR Train Score: 0.002118601876887949
# LR Test Score: -0.00284508238783876
# (6869, 146)
# Microsoft SQL Server
# LR Train Score: 0.021458063654423487
# LR Test Score: 0.024127487580927198
# (6869, 146)
# MongoDB
# LR Train Score: 0.00013666791168764902
# LR Test Score: -0.000693694099008102
# (6869, 146)
# MySQL
# LR Train Score: 0.001659102033921389
# LR Test Score: 0.0013142439327564759
# (6869, 146)
# Oracle
# LR Train Score: 0.002843187397419955
# LR Test Score: 0.001807411640381118
# (6869, 146)
# PostgreSQL
# LR Train Score: 0.003270084866282441
# LR Test Score: 0.0034045014802177587
# (6869, 146)
# Redis
# LR Train Score: 0.011401301305076106
# LR Test Score: 0.010413769236293335
# (6869, 146)
# SQLite
# LR Train Score: 0.00037988750339357225
# LR Test Score: -0.0017722948889664636
# (6869, 146)
# Academic researcher
# LR Train Score: 0.0011673168377327459
# LR Test Score: 0.002535026007596919
# (6869, 146)
# Data or business analyst
# LR Train Score: 0.007974274888266297
# LR Test Score: 0.00423471787832852
# (6869, 146)
# Data scientist or machine learning specialist
# LR Train Score: 0.0012746471145526073
# LR Test Score: -0.001460183532130399
# (6869, 146)
# Database administrator
# LR Train Score: 0.005202179816318542
# LR Test Score: 0.0024085707272205603
# (6869, 146)
# Designer
# LR Train Score: 0.006466741548514898
# LR Test Score: 0.002473979887428701
# (6869, 146)
# DevOps specialist
# LR Train Score: 0.0021835656097377587
# LR Test Score: 0.0011697575231023327
# (6869, 146)
# Developer, QA or test
# LR Train Score: 0.0068678559563002395
# LR Test Score: -0.0005538372364151112
# (6869, 146)
# Developer, back-end
# LR Train Score: 0.0031185773523934035
# LR Test Score: 0.004747379138550278
# (6869, 146)
# Developer, desktop or enterprise applications
# LR Train Score: 0.00020542817453550466
# LR Test Score: 0.0009763046677420117
# (6869, 146)
# Developer, embedded applications or devices
# LR Train Score: 0.0022749354431776947
# LR Test Score: 0.005096837212534289
# (6869, 146)
# Developer, front-end
# LR Train Score: 0.007962234350130104
# LR Test Score: 0.008153611501337976
# (6869, 146)
# Developer, full-stack
# LR Train Score: 0.006373410944842339
# LR Test Score: 0.01314250600395439
# (6869, 146)
# Developer, game or graphics
# LR Train Score: 6.942247098973287e-05
# LR Test Score: -0.00012171336413513423
# (6869, 146)
# Developer, mobile
# LR Train Score: 0.0004107665581170039
# LR Test Score: -0.0003284194221437886
# (6869, 146)
# Educator
# LR Train Score: 1.8271324028207303e-06
# LR Test Score: -7.902510342727709e-05
# (6869, 146)
# Engineer, data
# LR Train Score: 0.0013917592007005597
# LR Test Score: -0.0009058642572543629
# (6869, 146)
# Engineer, site reliability
# LR Train Score: 0.010403886428990816
# LR Test Score: 0.01722771729545791
# (6869, 146)
# Engineering manager
# LR Train Score: 0.02971445509532933
# LR Test Score: 0.020823422549309578
# (6869, 146)
# Marketing or sales professional
# LR Train Score: 1.0964086674114526e-05
# LR Test Score: -0.00013987795032366357
# (6869, 146)
# Product manager
# LR Train Score: 0.0012142893893618556
# LR Test Score: 0.00379994093435132
# (6869, 146)
# Scientist
# LR Train Score: 2.5375801666949194e-05
# LR Test Score: -0.000570057617600872
# (6869, 146)
# Senior executive/VP
# LR Train Score: 0.021290666763520982
# LR Test Score: 0.0002660520078239248
# (6869, 146)
# System administrator
# LR Train Score: 0.0013008890347422364
# LR Test Score: 0.0022477128760405307
# (6869, 146)
# Assembly
# LR Train Score: 0.0038070298272613323
# LR Test Score: 0.003910857228410891
# (6869, 146)
# Bash/Shell/PowerShell
# LR Train Score: 0.0044899535737350504
# LR Test Score: 0.0003086771719941206
# (6869, 146)
# C
# LR Train Score: 0.011907841869898128
# LR Test Score: 0.010041978203125357
# (6869, 146)
# C#
# LR Train Score: 0.017053080282119937
# LR Test Score: 0.01970634762162138
# (6869, 146)
# C++
# LR Train Score: 0.015525016932342095
# LR Test Score: 0.009628380730059671
# (6869, 146)
# Dart
# LR Train Score: -1.957756228243568e-06
# LR Test Score: -7.093030885485518e-05
# (6869, 146)
# Go
# LR Train Score: 0.024278897858365345
# LR Test Score: 0.027820002808087385
# (6869, 146)
# HTML/CSS
# LR Train Score: 0.02016395051231268
# LR Test Score: 0.03255151093704378
# (6869, 146)
# Haskell
# LR Train Score: 0.0023632602173386807
# LR Test Score: -0.002056893533007864
# (6869, 146)
# Java
# LR Train Score: 0.006004540755010113
# LR Test Score: 0.004760156713105812
# (6869, 146)
# JavaScript
# LR Train Score: 0.014514709236547962
# LR Test Score: 0.0054386749483928964
# (6869, 146)
# Julia
# LR Train Score: 0.0001129979839697981
# LR Test Score: -0.0013486344104609582
# (6869, 146)
# Kotlin
# LR Train Score: 0.00047995182774940304
# LR Test Score: 0.003619984463002157
# (6869, 146)
# Objective-C
# LR Train Score: 0.005694889976488593
# LR Test Score: 0.008790163439246212
# (6869, 146)
# PHP
# LR Train Score: 0.008480587098739112
# LR Test Score: 0.0036012858077237864
# (6869, 146)
# Perl
# LR Train Score: 0.003165003897187657
# LR Test Score: -0.0005130476185404298
# (6869, 146)
# Python
# LR Train Score: 0.006570050162214236
# LR Test Score: -0.0004935543838653356
# (6869, 146)
# R
# LR Train Score: 0.00016505539187550156
# LR Test Score: 0.0016926768939956593
# (6869, 146)
# Ruby
# LR Train Score: 0.004480331444464691
# LR Test Score: 0.00021365395283412525
# (6869, 146)
# Rust
# LR Train Score: 0.011382467374098537
# LR Test Score: 0.013075370819882304
# (6869, 146)
# SQL
# LR Train Score: 0.009864785946712917
# LR Test Score: 0.006237892082964658
# (6869, 146)
# Scala
# LR Train Score: 0.011068864382386523
# LR Test Score: 0.011501819182054174
# (6869, 146)
# Swift
# LR Train Score: 0.0027795801525016817
# LR Test Score: 0.005775373124651928
# (6869, 146)
# TypeScript
# LR Train Score: 5.9376456782445075e-06
# LR Test Score: -0.002584019762523093
# (6869, 146)
# VBA
# LR Train Score: 0.0048401806531861435
# LR Test Score: 0.004543826544502805
# (6869, 146)
# .NET
# LR Train Score: 0.01249972951908429
# LR Test Score: 0.022078616758940406
# (6869, 146)
# .NET Core
# LR Train Score: 0.006710767698318132
# LR Test Score: 0.0066826544710977265
# (6869, 146)
# Ansible
# LR Train Score: 0.0018363947576478523
# LR Test Score: 0.001432799800461182
# (6869, 146)
# Apache Spark
# LR Train Score: 0.00793885423541063
# LR Test Score: 0.002297137784538328
# (6869, 146)
# Chef
# LR Train Score: 0.009464838498469907
# LR Test Score: -0.0037537410938166538
# (6869, 146)
# Cordova
# LR Train Score: 0.0008301388176567004
# LR Test Score: -0.0029816974630694215
# (6869, 146)
# Flutter
# LR Train Score: 0.0010878425950952009
# LR Test Score: -0.0039337387386007006
# (6869, 146)
# Hadoop
# LR Train Score: 0.009530596525839985
# LR Test Score: -0.0035558478870032495
# (6869, 146)
# Keras
# LR Train Score: 0.0006702754287311041
# LR Test Score: -0.0027404237395256548
# (6869, 146)
# Node.js
# LR Train Score: 0.0012108300341777678
# LR Test Score: 0.0004878094012185086
# (6869, 146)
# Pandas
# LR Train Score: 0.00019282042308566005
# LR Test Score: -0.00028238818977666114
# (6869, 146)
# Puppet
# LR Train Score: 0.004890027545482067
# LR Test Score: 0.004500870405842017
# (6869, 146)
# React Native
# LR Train Score: 0.0003599503872349086
# LR Test Score: -0.000837589230134661
# (6869, 146)
# TensorFlow
# LR Train Score: 0.002905293760779859
# LR Test Score: -0.00048583044146832677
# (6869, 146)
# Teraform
# LR Train Score: 0.009245949038161894
# LR Test Score: 0.01398916125854155
# (6869, 146)
# Torch/PyTorch
# LR Train Score: 0.0015922565382452403
# LR Test Score: -0.000848035512402534
# (6869, 146)
# Unity 3D
# LR Train Score: 7.313546080633948e-05
# LR Test Score: 0.0008854387904837502
# (6869, 146)
# Unreal Engine
# LR Train Score: 1.219961216480936e-05
# LR Test Score: -0.00035962498337238635
# (6869, 146)
# Xamarin
# LR Train Score: 0.002257842832600776
# LR Test Score: 0.00160230292780561
# (6869, 146)
# Confluence
# LR Train Score: 0.016182942166914738
# LR Test Score: 0.00027538845206831475
# (6869, 146)
# Facebook Workplace
# LR Train Score: 0.009220384173323937
# LR Test Score: 0.004397336664078599
# (6869, 146)
# Github
# LR Train Score: 0.0029481712892299727
# LR Test Score: 0.004338201110859807
# (6869, 146)
# Gitlab
# LR Train Score: 0.0001130331122858319
# LR Test Score: -9.159444732786959e-05
# (6869, 146)
# Google Suite (Docs, Meet, etc)
# LR Train Score: 0.008919172522225516
# LR Test Score: 0.015346972489403643
# (6869, 146)
# Jira
# LR Train Score: 0.006105967539415946
# LR Test Score: 0.009419697408502903
# (6869, 146)
# Microsoft Azure
# LR Train Score: 0.0060608102624215565
# LR Test Score: 0.00570805144768427
# (6869, 146)
# Microsoft Teams
# LR Train Score: 0.009144000759967907
# LR Test Score: 0.012478481834208188
# (6869, 146)
# Slack
# LR Train Score: 0.00471540581538743
# LR Test Score: 0.008308974398112401
# (6869, 146)
# Stack Overflow for Teams
# LR Train Score: 0.007096269457963711
# LR Test Score: 0.000630476582593742
# (6869, 146)
# Trello
# LR Train Score: 0.0008724512133331253
# LR Test Score: 0.001947249815046126
# (6869, 146)
# AWS
# LR Train Score: 0.010624995027270323
# LR Test Score: 0.009938654008946668
# (6869, 146)
# Android
# LR Train Score: 0.0002928572308744659
# LR Test Score: -0.0010690516513343074
# (6869, 146)
# Arduino
# LR Train Score: 0.00043357052155656994
# LR Test Score: -0.0006728395957142919
# (6869, 146)
# Docker
# LR Train Score: 0.014036032842594248
# LR Test Score: 0.0025173939779474797
# (6869, 146)
# Google Cloud Platform
# LR Train Score: 0.010605560025103933
# LR Test Score: 0.006259834206793546
# (6869, 146)
# Heroku
# LR Train Score: 2.669876957173134e-05
# LR Test Score: -0.0004228738701699264
# (6869, 146)
# IBM Cloud or Watson
# LR Train Score: 6.159225875290719e-05
# LR Test Score: -0.00011980916665454977
# (6869, 146)
# Kubernetes
# LR Train Score: 0.01646617288112673
# LR Test Score: 0.017336878875193973
# (6869, 146)
# Linux
# LR Train Score: 0.011502505334869961
# LR Test Score: 0.025830658960685704
# (6869, 146)
# MacOS
# LR Train Score: 0.012359218264548777
# LR Test Score: 0.008862844734820907
# (6869, 146)
# Microsoft Azure
# LR Train Score: 0.007668434973309379
# LR Test Score: -0.00302610961056593
# (6869, 146)
# Raspberry Pi
# LR Train Score: 0.0007321366194904533
# LR Test Score: -0.003599795198533373
# (6869, 146)
# Slack Apps and Integrations
# LR Train Score: 0.0024618988585525248
# LR Test Score: 5.825807668724536e-06
# (6869, 146)
# Windows
# LR Train Score: 0.02425500523815305
# LR Test Score: 0.026065610177944176
# (6869, 146)
# WordPress
# LR Train Score: 0.005889022146256195
# LR Test Score: 0.007252142858743871
# (6869, 146)
# iOS
# LR Train Score: 0.003978019342371741
# LR Test Score: 0.00409642917189168
# (6869, 146)
# ASP.NET
# LR Train Score: 0.01759817653179474
# LR Test Score: 0.004782348006552195
# (6869, 146)
# ASP.NET Core
# LR Train Score: 0.010660248860873467
# LR Test Score: 0.005943425783265455
# (6869, 146)
# Angular
# LR Train Score: 0.0013328316094076698
# LR Test Score: 0.0016870336166506794
# (6869, 146)
# Angular.js
# LR Train Score: 0.0018513261375497914
# LR Test Score: -0.001683562405979222
# (6869, 146)
# Django
# LR Train Score: 0.0003334875285004868
# LR Test Score: -0.00021136886095685092
# (6869, 146)
# Drupal
# LR Train Score: 0.00265077315974116
# LR Test Score: 0.0029908969186055456
# (6869, 146)
# Express
# LR Train Score: 4.767284785334169e-05
# LR Test Score: 0.0006108000775395528
# (6869, 146)
# Flask
# LR Train Score: 0.0013324569392738628
# LR Test Score: -0.0025369747893602135
# (6869, 146)
# Gatsby
# LR Train Score: 9.584391182149155e-05
# LR Test Score: -8.777961027606196e-06
# (6869, 146)
# Laravel
# LR Train Score: 0.002098241448177829
# LR Test Score: 0.0038133493580083666
# (6869, 146)
# React.js
# LR Train Score: 0.00017459830366939322
# LR Test Score: -0.0010707195548047554
# (6869, 146)
# Ruby on Rails
# LR Train Score: 0.0007245752349519519
# LR Test Score: -0.0014705962683936313
# (6869, 146)
# Spring
# LR Train Score: 0.0016512600551815693
# LR Test Score: 0.0017390279426872102
# (6869, 146)
# Symfony
# LR Train Score: 0.002043761337167993
# LR Test Score: 0.0005663803031942249
# (6869, 146)
# Vue.js
# LR Train Score: 0.0023368614602029547
# LR Test Score: 0.005510362989641915
# (6869, 146)
# jQuery
# LR Train Score: 0.024113299442190872
# LR Test Score: 0.019231164324619576

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
X=df[(df['ConvertedComp']<=200000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
X=X[X['Country']=='United States'][['ConvertedComp']]
# X=X[['ConvertedComp']]
for each_col in numericals:
    X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
for each_col in categoricals: 
    X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
for each_col in multi_options: 
    X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)    
input_ary=X.dropna().drop('ConvertedComp', axis=1)
y=X.dropna()['ConvertedComp']
print(input_ary.shape)
print(sorted(input_ary.columns))
X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
rfr=RandomForestRegressor()
rfr.fit(X_train, y_train)
print(f'Train Score: {rfr.score(X_train, y_train)}')
print(f'Test Score: {rfr.score(X_test, y_test)}')
# Out:
# (5485, 351)
# ['.NET', '.NET Core', 'A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'ASP.NET', 'ASP.NET Core', 'AWS', 'Academic researcher', 'Afghanistan', 'Age', 'Age1stCode', 'Albania', 'Algeria', 'Andorra', 'Android', 'Angola', 'Angular', 'Angular.js', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Ansible', 'Antigua and Barbuda', 'Apache Spark', 'Arduino', 'Argentina', 'Armenia', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Australia', 'Austria', 'Azerbaijan', 'BSD', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Bash/Shell/PowerShell', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'C', 'C#', 'C++', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cassandra', 'Chad', 'Chef', 'Chile', 'China', 'Colombia', 'Computer science, computer engineering, or software engineering', 'Confluence', 'Congo, Republic of the...', 'Cordova', 'Costa Rica', 'Couchbase', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", 'Dart', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Democratic Republic of the Congo', 'Denmark', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Django', 'Djibouti', 'Docker', 'Dominican Republic', 'Drupal', 'DynamoDB', 'Ecuador', 'Educator', 'Egypt', 'El Salvador', 'Elasticsearch', 'Employed full-time', 'Employed part-time', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Eritrea', 'Estonia', 'Ethiopia', 'Express', 'Facebook Workplace', 'Fiji', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Finland', 'Firebase', 'Flask', 'Flutter', 'France', 'Gabon', 'Gambia', 'Gatsby', 'Georgia', 'Germany', 'Ghana', 'Github', 'Gitlab', 'Go', 'Google Cloud Platform', 'Google Suite (Docs, Meet, etc)', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana', 'HTML/CSS', 'Hadoop', 'Haiti', 'Haskell', 'Heroku', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'I am a developer by profession', 'I am a student who is learning to code', 'I am not primarily a developer, but I write code sometimes as part of my work', 'I code primarily as a hobby', 'I never completed any formal education', 'I never declared a major', 'I used to be a developer by profession, but no longer am', 'IBM Cloud or Watson', 'IBM DB2', 'Iceland', 'Independent contractor, freelancer, or self-employed', 'India', 'Indonesia', 'Information systems, information technology, or system administration', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Java', 'JavaScript', 'Jira', 'Jordan', 'Julia', 'Kazakhstan', 'Kenya', 'Keras', 'Kiribati', 'Kosovo', 'Kotlin', 'Kubernetes', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Laravel', 'Latvia', 'Lebanon', 'Lesotho', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Linux', 'Linux-based', 'Lithuania', 'Luxembourg', 'MacOS', 'MacOS', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Man', 'MariaDB', 'Marketing or sales professional', 'Marshall Islands', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Federated States of...', 'Microsoft Azure', 'Microsoft Azure', 'Microsoft SQL Server', 'Microsoft Teams', 'Monaco', 'MongoDB', 'Mongolia', 'Montenegro', 'Moro ...
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Train Score: 0.8840414379792266
# Test Score: 0.3056189375362348

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=['YearsCodePro']
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=['EdLevel']
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
# input_ary=X.dropna()[['YearsCodePro']]
# y=X.dropna()['ConvertedComp']
X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
lr.fit(input_ary, y)
lr.score(input_ary, y)
# Out:
# 0.12199551738677772

# %%
# print(numericals)
# numericals=['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
numericals=['YearsCodePro']
# print(categoricals)
# categoricals=['MainBranch', 'Country', 'EdLevel', 'Employment', 'OpSys', 'UndergradMajor']
categoricals=['EdLevel']
# print(multi_options)
# multi_options=['DatabaseWorkedWith', 'DevType', 'Gender', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
multi_options=['DatabaseWorkedWith', 'DevType', 'LanguageWorkedWith', 'MiscTechWorkedWith', 'NEWCollabToolsWorkedWith', 'PlatformWorkedWith', 'WebframeWorkedWith']
# multi_options=['DevType']
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
X=df[(df['ConvertedComp']<=200000) & (df['ConvertedComp']>=20000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
X=X[X['Country']=='United States'][['ConvertedComp']]
# X=X[['ConvertedComp']]
for each_col in numericals:
    X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
for each_col in categoricals: 
    X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
for each_col in multi_options: 
    X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)    
input_ary=X.dropna().drop('ConvertedComp', axis=1)
y=X.dropna()['ConvertedComp']
print(input_ary.shape)
print(sorted(input_ary.columns))
X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
rfr=RandomForestRegressor()
rfr.fit(X_train, y_train)
print(f'Train Score: {rfr.score(X_train, y_train)}')
print(f'Test Score: {rfr.score(X_test, y_test)}')
# Out:
# (6266, 134)
# ['.NET', '.NET Core', 'ASP.NET', 'ASP.NET Core', 'AWS', 'Academic researcher', 'Android', 'Angular', 'Angular.js', 'Ansible', 'Apache Spark', 'Arduino', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bash/Shell/PowerShell', 'C', 'C#', 'C++', 'Cassandra', 'Chef', 'Confluence', 'Cordova', 'Couchbase', 'Dart', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Django', 'Docker', 'Drupal', 'DynamoDB', 'Educator', 'Elasticsearch', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Express', 'Facebook Workplace', 'Firebase', 'Flask', 'Flutter', 'Gatsby', 'Github', 'Gitlab', 'Go', 'Google Cloud Platform', 'Google Suite (Docs, Meet, etc)', 'HTML/CSS', 'Hadoop', 'Haskell', 'Heroku', 'I never completed any formal education', 'IBM Cloud or Watson', 'IBM DB2', 'Java', 'JavaScript', 'Jira', 'Julia', 'Keras', 'Kotlin', 'Kubernetes', 'Laravel', 'Linux', 'MacOS', 'MariaDB', 'Marketing or sales professional', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Microsoft Azure', 'Microsoft Azure', 'Microsoft SQL Server', 'Microsoft Teams', 'MongoDB', 'MySQL', 'Node.js', 'Objective-C', 'Oracle', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'PHP', 'Pandas', 'Perl', 'PostgreSQL', 'Primary/elementary school', 'Product manager', 'Professional degree (JD, MD, etc.)', 'Puppet', 'Python', 'R', 'Raspberry Pi', 'React Native', 'React.js', 'Redis', 'Ruby', 'Ruby on Rails', 'Rust', 'SQL', 'SQLite', 'Scala', 'Scientist', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senior executive/VP', 'Slack', 'Slack Apps and Integrations', 'Some college/university study without earning a degree', 'Spring', 'Stack Overflow for Teams', 'Swift', 'Symfony', 'System administrator', 'TensorFlow', 'Teraform', 'Torch/PyTorch', 'Trello', 'TypeScript', 'Unity 3D', 'Unreal Engine', 'VBA', 'Vue.js', 'Windows', 'WordPress', 'Xamarin', 'YearsCodePro', 'iOS', 'jQuery']
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Train Score: 0.8720514758163158
# Test Score: 0.3152367888207218

# %%
rfr.feature_importances_
# Out:
# array([1.90462542e-01, 2.20316171e-03, 7.83955470e-03, 1.95109854e-04,
#        9.75006222e-03, 5.51221765e-03, 2.46978698e-05, 5.75792434e-03,
#        1.66195332e-03, 4.87366424e-03, 5.12241151e-03, 2.22795933e-03,
#        1.06589724e-02, 4.44722390e-03, 4.18502589e-03, 1.04371313e-03,
#        2.99700732e-03, 1.84110345e-02, 4.52112901e-03, 7.71424149e-03,
#        6.75889876e-03, 9.39599194e-03, 6.78582148e-03, 6.51690959e-03,
#        6.05773008e-03, 4.68826309e-03, 3.62004357e-03, 2.58900303e-03,
#        4.14700337e-03, 4.20777781e-03, 2.81920437e-03, 8.41752070e-03,
#        6.90229646e-03, 5.64756866e-03, 8.57277726e-03, 9.07127768e-03,
#        2.34590429e-03, 5.80534108e-03, 2.76418382e-03, 4.25862335e-03,
#        5.43546903e-03, 1.39315136e-02, 1.71286539e-03, 6.04019290e-03,
#        4.46361397e-03, 1.10814904e-02, 4.25655782e-03, 6.05108588e-03,
#        8.68109330e-03, 7.70860554e-03, 9.75345841e-03, 1.65188212e-02,
#        1.50837063e-03, 1.39745115e-02, 1.52121345e-02, 4.46729949e-03,
#        7.25972885e-03, 9.94145810e-03, 2.39109403e-03, 5.72967760e-03,
#        9.01406228e-03, 1.07117253e-02, 3.96057138e-03, 7.98019808e-03,
#        6.62281862e-03, 5.07605735e-03, 1.30648408e-02, 9.84668857e-03,
#        7.71884490e-03, 3.89031911e-03, 9.23099890e-03, 5.44807636e-03,
#        5.39486519e-03, 2.88654227e-03, 1.85798972e-03, 4.41125068e-03,
#        3.63897061e-03, 9.87789303e-04, 3.78393615e-04, 5.15861737e-03,
#        1.77192815e-03, 6.65678819e-03, 5.56207376e-03, 5.70477931e-03,
#        3.60400094e-03, 3.30289797e-03, 3.39407448e-03, 3.67771903e-03,
#        1.79383268e-03, 1.04238763e-03, 9.94514988e-04, 1.19593501e-02,
#        1.56480079e-02, 1.09414330e-02, 7.94401826e-03, 1.09949398e-02,
#        1.24762496e-02, 6.68435424e-03, 8.06014423e-03, 1.14998895e-02,
#        6.67431416e-03, 5.72492684e-03, 8.29777348e-03, 4.67358741e-03,
#        2.48982907e-03, 1.11067592e-02, 1.31275834e-02, 4.23946318e-03,
#        1.12906879e-03, 7.11938516e-03, 9.98039353e-03, 8.79011252e-03,
#        4.73572202e-03, 3.98908377e-03, 3.01965831e-03, 1.54048059e-02,
#        6.49362662e-03, 5.87516302e-03, 3.12160658e-03, 2.10422559e-03,
#        4.63031233e-03, 5.88787931e-03, 2.34949744e-03, 9.41150958e-04,
#        4.55129499e-03, 4.48057375e-03, 2.11852837e-03, 3.65101311e-03,
#        6.73828016e-03, 2.88472150e-03, 4.78548020e-03, 4.54433755e-04,
#        3.00084173e-03, 1.73351108e-02])

# %%
X['YearsCodePro'].hist()

# %%
for each_col in numericals: 
    X[[each_col, 'ConvertedComp']].boxplot(by=each_col, showfliers=False, figsize=(20, 10))

# %%
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time') & (df['Age']>17) & (df['Age']<60)]#[['ConvertedComp']]
for each_col in numericals: 
    X[[each_col, 'ConvertedComp']].boxplot(by=each_col, showfliers=False, figsize=(20, 10))

# %%
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time') & (df['Age']>17) & (df['Age']<60)]#[['ConvertedComp']]
X[['YearsCodePro', 'ConvertedComp']].groupby('YearsCodePro').count().sort_values(by='YearsCodePro').plot()
X[['YearsCodePro', 'ConvertedComp']].groupby('YearsCodePro').count().sort_values(by='YearsCodePro')
# X[['YearsCodePro', 'ConvertedComp']].plot(kind='scatter', x='YearsCodePro', y='ConvertedComp')
# Out:
#                   ConvertedComp
# YearsCodePro
# 1                           539
# 10                         1124
# 11                          432
# 12                          648
# 13                          441
# 14                          360
# 15                          641
# 16                          301
# 17                          216
# 18                          220
# 19                          184
# 2                          1079
# 20                          623
# 21                          183
# 22                          212
# 23                          149
# 24                          118
# 25                          245
# 26                           81
# 27                           71
# 28                           61
# 29                           32
# 3                          1366
# 30                          108
# 31                           30
# 32                           50
# 33                           38
# 34                           29
# 35                           50
# 36                           17
# 37                           13
# 38                           18
# 39                            6
# 4                          1124
# 40                            9
# 41                            1
# 42                            2
# 43                            1
# 5                          1348
# 6                          1081
# 7                           919
# 8                           918
# 9                           538
# Less than 1 year            380

# %%
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time') & (df['Age']>17) & (df['Age']<60)]#[['ConvertedComp']]
X[['Age', 'ConvertedComp']].groupby('Age').median().plot()
X[['Age', 'ConvertedComp']].groupby('Age').median()
X[['Age', 'ConvertedComp']].plot(kind='scatter', x='Age', y='ConvertedComp')

# %%
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time') & (df['Age']>17) & (df['Age']<60)]#[['ConvertedComp']]
X[['Age1stCode', 'ConvertedComp']].boxplot(by='Age1stCode')
# X[['Age', 'ConvertedComp']].groupby('Age').median()
# X[['Age', 'ConvertedComp']].plot(kind='scatter', x='Age', y='ConvertedComp')

# %%
# # fig, ax=plt.subplots(math.ceil(len(numericals)/2), 2)
# # plt.subplots(math.ceil(5/2), 2)
for idx, each_col in enumerate(numericals): 
#     plt.scatter(input_ary[each_col], y, ax=ax[int(idx/2)][int(idx%2)])
    plt.scatter(input_ary[each_col], y)
    plt.title(each_col)
    plt.show()
#     print(ax[0][0])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
# X=df[['ConvertedComp']]
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
X=X[X['Country']=='United States'][['ConvertedComp']]
for each_col in numericals:
    X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
for each_col in categoricals: 
    X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
for each_col in multi_options: 
    X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)    
input_ary=X.dropna().drop('ConvertedComp', axis=1)
y=X.dropna()['ConvertedComp']
print(input_ary.shape)
print(sorted(input_ary.columns))
X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
rfr=RandomForestRegressor()
rfr.fit(X_train, y_train)
print(f'Train Score: {rfr.score(X_train, y_train)}')
print(f'Test Score: {rfr.score(X_test, y_test)}')
# Out:
# (5983, 157)
# ['.NET', '.NET Core', 'A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'ASP.NET', 'ASP.NET Core', 'AWS', 'Academic researcher', 'Age', 'Age1stCode', 'Android', 'Angular', 'Angular.js', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Ansible', 'Apache Spark', 'Arduino', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bash/Shell/PowerShell', 'C', 'C#', 'C++', 'Cassandra', 'Chef', 'Computer science, computer engineering, or software engineering', 'Confluence', 'Cordova', 'Couchbase', 'Dart', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Django', 'Docker', 'Drupal', 'DynamoDB', 'Educator', 'Elasticsearch', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Express', 'Facebook Workplace', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Firebase', 'Flask', 'Flutter', 'Gatsby', 'Github', 'Gitlab', 'Go', 'Google Cloud Platform', 'Google Suite (Docs, Meet, etc)', 'HTML/CSS', 'Hadoop', 'Haskell', 'Heroku', 'I am a developer by profession', 'I am a student who is learning to code', 'I am not primarily a developer, but I write code sometimes as part of my work', 'I code primarily as a hobby', 'I never completed any formal education', 'I never declared a major', 'I used to be a developer by profession, but no longer am', 'IBM Cloud or Watson', 'IBM DB2', 'Information systems, information technology, or system administration', 'Java', 'JavaScript', 'Jira', 'Julia', 'Keras', 'Kotlin', 'Kubernetes', 'Laravel', 'Linux', 'MacOS', 'Man', 'MariaDB', 'Marketing or sales professional', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Microsoft Azure', 'Microsoft Azure', 'Microsoft SQL Server', 'Microsoft Teams', 'MongoDB', 'MySQL', 'Node.js', 'Non-binary, genderqueer, or gender non-conforming', 'Objective-C', 'Oracle', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'PHP', 'Pandas', 'Perl', 'PostgreSQL', 'Primary/elementary school', 'Product manager', 'Professional degree (JD, MD, etc.)', 'Puppet', 'Python', 'R', 'Raspberry Pi', 'React Native', 'React.js', 'Redis', 'Ruby', 'Ruby on Rails', 'Rust', 'SQL', 'SQLite', 'Scala', 'Scientist', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senior executive/VP', 'Slack', 'Slack Apps and Integrations', 'Some college/university study without earning a degree', 'Spring', 'Stack Overflow for Teams', 'Swift', 'Symfony', 'System administrator', 'TensorFlow', 'Teraform', 'Torch/PyTorch', 'Trello', 'TypeScript', 'Unity 3D', 'Unreal Engine', 'VBA', 'Vue.js', 'Web development or web design', 'Windows', 'Woman', 'WordPress', 'Xamarin', 'YearsCode', 'YearsCodePro', 'iOS', 'jQuery']
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Train Score: 0.8616210803147671
# Test Score: 0.2299291117147706

# %%
columns=3
columns_list=input_ary.columns
fig, ax=plt.subplots(math.ceil(len(columns_list)/columns), columns, figsize=(10, 100))
for idx, each_col in enumerate(columns_list): 
    print(f'Graphing {each_col}: {len(input_ary[each_col])} x {len(y)}')
    ax[int(idx/columns)][idx%columns].scatter(input_ary[each_col], y)
    
# # ax[int(idx/columns)][idx%columns]
# Out:
# Graphing Age: 5983 x 5983
# Graphing Age1stCode: 5983 x 5983
# Graphing YearsCode: 5983 x 5983
# Graphing YearsCodePro: 5983 x 5983
# Graphing I am a developer by profession: 5983 x 5983
# Graphing I am a student who is learning to code: 5983 x 5983
# Graphing I am not primarily a developer, but I write code sometimes as part of my work: 5983 x 5983
# Graphing I code primarily as a hobby: 5983 x 5983
# Graphing I used to be a developer by profession, but no longer am: 5983 x 5983
# Graphing Associate degree (A.A., A.S., etc.): 5983 x 5983
# Graphing Bachelor’s degree (B.A., B.S., B.Eng., etc.): 5983 x 5983
# Graphing I never completed any formal education: 5983 x 5983
# Graphing Master’s degree (M.A., M.S., M.Eng., MBA, etc.): 5983 x 5983
# Graphing Other doctoral degree (Ph.D., Ed.D., etc.): 5983 x 5983
# Graphing Primary/elementary school: 5983 x 5983
# Graphing Professional degree (JD, MD, etc.): 5983 x 5983
# Graphing Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.): 5983 x 5983
# Graphing Some college/university study without earning a degree: 5983 x 5983
# Graphing A business discipline (such as accounting, finance, marketing, etc.): 5983 x 5983
# Graphing A health science (such as nursing, pharmacy, radiology, etc.): 5983 x 5983
# Graphing A humanities discipline (such as literature, history, philosophy, etc.): 5983 x 5983
# Graphing A natural science (such as biology, chemistry, physics, etc.): 5983 x 5983
# Graphing A social science (such as anthropology, psychology, political science, etc.): 5983 x 5983
# Graphing Another engineering discipline (such as civil, electrical, mechanical, etc.): 5983 x 5983
# Graphing Computer science, computer engineering, or software engineering: 5983 x 5983
# Graphing Fine arts or performing arts (such as graphic design, music, studio art, etc.): 5983 x 5983
# Graphing I never declared a major: 5983 x 5983
# Graphing Information systems, information technology, or system administration: 5983 x 5983
# Graphing Mathematics or statistics: 5983 x 5983
# Graphing Web development or web design: 5983 x 5983
# Graphing Cassandra: 5983 x 5983
# Graphing Couchbase: 5983 x 5983
# Graphing DynamoDB: 5983 x 5983
# Graphing Elasticsearch: 5983 x 5983
# Graphing Firebase: 5983 x 5983
# Graphing IBM DB2: 5983 x 5983
# Graphing MariaDB: 5983 x 5983
# Graphing Microsoft SQL Server: 5983 x 5983
# Graphing MongoDB: 5983 x 5983
# Graphing MySQL: 5983 x 5983
# Graphing Oracle: 5983 x 5983
# Graphing PostgreSQL: 5983 x 5983
# Graphing Redis: 5983 x 5983
# Graphing SQLite: 5983 x 5983
# Graphing Academic researcher: 5983 x 5983
# Graphing Data or business analyst: 5983 x 5983
# Graphing Data scientist or machine learning specialist: 5983 x 5983
# Graphing Database administrator: 5983 x 5983
# Graphing Designer: 5983 x 5983
# Graphing DevOps specialist: 5983 x 5983
# Graphing Developer, QA or test: 5983 x 5983
# Graphing Developer, back-end: 5983 x 5983
# Graphing Developer, desktop or enterprise applications: 5983 x 5983
# Graphing Developer, embedded applications or devices: 5983 x 5983
# Graphing Developer, front-end: 5983 x 5983
# Graphing Developer, full-stack: 5983 x 5983
# Graphing Developer, game or graphics: 5983 x 5983
# Graphing Developer, mobile: 5983 x 5983
# Graphing Educator: 5983 x 5983
# Graphing Engineer, data: 5983 x 5983
# Graphing Engineer, site reliability: 5983 x 5983
# Graphing Engineering manager: 5983 x 5983
# Graphing Marketing or sales professional: 5983 x 5983
# Graphing Product manager: 5983 x 5983
# Graphing Scientist: 5983 x 5983
# Graphing Senior executive/VP: 5983 x 5983
# Graphing System administrator: 5983 x 5983
# Graphing Man: 5983 x 5983
# Graphing Non-binary, genderqueer, or gender non-conforming: 5983 x 5983
# Graphing Woman: 5983 x 5983
# Graphing Assembly: 5983 x 5983
# Graphing Bash/Shell/PowerShell: 5983 x 5983
# Graphing C: 5983 x 5983
# Graphing C#: 5983 x 5983
# Graphing C++: 5983 x 5983
# Graphing Dart: 5983 x 5983
# Graphing Go: 5983 x 5983
# Graphing HTML/CSS: 5983 x 5983
# Graphing Haskell: 5983 x 5983
# Graphing Java: 5983 x 5983
# Graphing JavaScript: 5983 x 5983
# Graphing Julia: 5983 x 5983
# Graphing Kotlin: 5983 x 5983
# Graphing Objective-C: 5983 x 5983
# Graphing PHP: 5983 x 5983
# Graphing Perl: 5983 x 5983
# Graphing Python: 5983 x 5983
# Graphing R: 5983 x 5983
# Graphing Ruby: 5983 x 5983
# Graphing Rust: 5983 x 5983
# Graphing SQL: 5983 x 5983
# Graphing Scala: 5983 x 5983
# Graphing Swift: 5983 x 5983
# Graphing TypeScript: 5983 x 5983
# Graphing VBA: 5983 x 5983
# Graphing .NET: 5983 x 5983
# Graphing .NET Core: 5983 x 5983
# Graphing Ansible: 5983 x 5983
# Graphing Apache Spark: 5983 x 5983
# Graphing Chef: 5983 x 5983
# Graphing Cordova: 5983 x 5983
# Graphing Flutter: 5983 x 5983
# Graphing Hadoop: 5983 x 5983
# Graphing Keras: 5983 x 5983
# Graphing Node.js: 5983 x 5983
# Graphing Pandas: 5983 x 5983
# Graphing Puppet: 5983 x 5983
# Graphing React Native: 5983 x 5983
# Graphing TensorFlow: 5983 x 5983
# Graphing Teraform: 5983 x 5983
# Graphing Torch/PyTorch: 5983 x 5983
# Graphing Unity 3D: 5983 x 5983
# Graphing Unreal Engine: 5983 x 5983
# Graphing Xamarin: 5983 x 5983
# Graphing Confluence: 5983 x 5983
# Graphing Facebook Workplace: 5983 x 5983
# Graphing Github: 5983 x 5983
# Graphing Gitlab: 5983 x 5983
# Graphing Google Suite (Docs, Meet, etc): 5983 x 5983
# Graphing Jira: 5983 x 5983
# Graphing Microsoft Azure: 5983 x 5983
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-bfb7cb69bbe5> in <module>
#       4 for idx, each_col in enumerate(columns_list):
#       5     print(f'Graphing {each_col}: {len(input_ary[each_col])} x {len(y)}')
# ----> 6     ax[int(idx/columns)][idx%columns].scatter(input_ary[each_col], y)
#       7 # # ax[int(idx/columns)][idx%columns]
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# -> 4444             raise ValueError("x and y must be the same size")
#    4445
#    4446         if s is None:
#
# ValueError: x and y must be the same size

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
# X=df[['ConvertedComp']]
# categoricals=['MainBranch', 'EdLevel', 'UndergradMajor']#, 'Country']
X=df[(df['ConvertedComp']<=500000) & (df['ConvertedComp']>=40000) & (df['Employment']=='Employed full-time')]#[['ConvertedComp']]
X=X[X['Country']=='United States'][['ConvertedComp']]
for each_col in numericals:
    X=pd.concat([X, pd.to_numeric(df[each_col], errors='coerce')], axis=1)
for each_col in categoricals: 
    X=pd.concat([X, pd.get_dummies(df[each_col])], axis=1)
for each_col in multi_options: 
    X=pd.concat([X, df[each_col].str.get_dummies(sep=';')], axis=1)    
input_ary=X.dropna().drop('ConvertedComp', axis=1)
y=X.dropna()['ConvertedComp']
print(input_ary.shape)
print(sorted(input_ary.columns))
X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
rfr=RandomForestRegressor()
rfr.fit(X_train, y_train)
print(f'Train Score: {rfr.score(X_train, y_train)}')
print(f'Test Score: {rfr.score(X_test, y_test)}')
# Out:
# (5983, 157)
# ['.NET', '.NET Core', 'A business discipline (such as accounting, finance, marketing, etc.)', 'A health science (such as nursing, pharmacy, radiology, etc.)', 'A humanities discipline (such as literature, history, philosophy, etc.)', 'A natural science (such as biology, chemistry, physics, etc.)', 'A social science (such as anthropology, psychology, political science, etc.)', 'ASP.NET', 'ASP.NET Core', 'AWS', 'Academic researcher', 'Age', 'Age1stCode', 'Android', 'Angular', 'Angular.js', 'Another engineering discipline (such as civil, electrical, mechanical, etc.)', 'Ansible', 'Apache Spark', 'Arduino', 'Assembly', 'Associate degree (A.A., A.S., etc.)', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Bash/Shell/PowerShell', 'C', 'C#', 'C++', 'Cassandra', 'Chef', 'Computer science, computer engineering, or software engineering', 'Confluence', 'Cordova', 'Couchbase', 'Dart', 'Data or business analyst', 'Data scientist or machine learning specialist', 'Database administrator', 'Designer', 'DevOps specialist', 'Developer, QA or test', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, embedded applications or devices', 'Developer, front-end', 'Developer, full-stack', 'Developer, game or graphics', 'Developer, mobile', 'Django', 'Docker', 'Drupal', 'DynamoDB', 'Educator', 'Elasticsearch', 'Engineer, data', 'Engineer, site reliability', 'Engineering manager', 'Express', 'Facebook Workplace', 'Fine arts or performing arts (such as graphic design, music, studio art, etc.)', 'Firebase', 'Flask', 'Flutter', 'Gatsby', 'Github', 'Gitlab', 'Go', 'Google Cloud Platform', 'Google Suite (Docs, Meet, etc)', 'HTML/CSS', 'Hadoop', 'Haskell', 'Heroku', 'I am a developer by profession', 'I am a student who is learning to code', 'I am not primarily a developer, but I write code sometimes as part of my work', 'I code primarily as a hobby', 'I never completed any formal education', 'I never declared a major', 'I used to be a developer by profession, but no longer am', 'IBM Cloud or Watson', 'IBM DB2', 'Information systems, information technology, or system administration', 'Java', 'JavaScript', 'Jira', 'Julia', 'Keras', 'Kotlin', 'Kubernetes', 'Laravel', 'Linux', 'MacOS', 'Man', 'MariaDB', 'Marketing or sales professional', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Mathematics or statistics', 'Microsoft Azure', 'Microsoft Azure', 'Microsoft SQL Server', 'Microsoft Teams', 'MongoDB', 'MySQL', 'Node.js', 'Non-binary, genderqueer, or gender non-conforming', 'Objective-C', 'Oracle', 'Other doctoral degree (Ph.D., Ed.D., etc.)', 'PHP', 'Pandas', 'Perl', 'PostgreSQL', 'Primary/elementary school', 'Product manager', 'Professional degree (JD, MD, etc.)', 'Puppet', 'Python', 'R', 'Raspberry Pi', 'React Native', 'React.js', 'Redis', 'Ruby', 'Ruby on Rails', 'Rust', 'SQL', 'SQLite', 'Scala', 'Scientist', 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)', 'Senior executive/VP', 'Slack', 'Slack Apps and Integrations', 'Some college/university study without earning a degree', 'Spring', 'Stack Overflow for Teams', 'Swift', 'Symfony', 'System administrator', 'TensorFlow', 'Teraform', 'Torch/PyTorch', 'Trello', 'TypeScript', 'Unity 3D', 'Unreal Engine', 'VBA', 'Vue.js', 'Web development or web design', 'Windows', 'Woman', 'WordPress', 'Xamarin', 'YearsCode', 'YearsCodePro', 'iOS', 'jQuery']
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Train Score: 0.8552610858985985
# Test Score: 0.21086560445563463

# %%
sorted(list(zip(rfr.feature_importances_, input_ary.columns)), reverse=True)
# Out:
# [(0.19046254197770188, 'YearsCodePro'),
#  (0.01841103450408082, 'Microsoft SQL Server'),
#  (0.017335110821957506, 'jQuery'),
#  (0.016518821204849418, 'C++'),
#  (0.015648007857340246, 'Facebook Workplace'),
#  (0.015404805936876789, 'Windows'),
#  (0.015212134479529182, 'HTML/CSS'),
#  (0.013974511510984847, 'Go'),
#  (0.013931513626058475, 'Engineering manager'),
#  (0.013127583424824769, 'Google Cloud Platform'),
#  (0.013064840797182875, 'Rust'),
#  (0.012476249625394321, 'Jira'),
#  (0.011959350121924372, 'Confluence'),
#  (0.011499889484540943, 'Slack'),
#  (0.011106759161237932, 'Docker'),
#  (0.011081490402033467, 'Senior executive/VP'),
#  (0.010994939786895388, 'Google Suite (Docs, Meet, etc)'),
#  (0.01094143300609074, 'Github'),
#  (0.010711725268556002, 'PHP'),
#  (0.010658972392020601, 'DynamoDB'),
#  (0.009980393532015082, 'Linux'),
#  (0.009941458102783263, 'JavaScript'),
#  (0.009846688565832692, 'SQL'),
#  (0.009753458407202358, 'C#'),
#  (0.009750062221147177, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'),
#  (0.009395991939491104, 'PostgreSQL'),
#  (0.009230998900896214, 'TypeScript'),
#  (0.009071277677511431, 'Developer, full-stack'),
#  (0.009014062280922757, 'Objective-C'),
#  (0.008790112516622227, 'MacOS'),
#  (0.008681093297320546, 'Bash/Shell/PowerShell'),
#  (0.008572777259229338, 'Developer, front-end'),
#  (0.008417520698453777, 'Developer, back-end'),
#  (0.008297773484349336, 'AWS'),
#  (0.00806014422800822, 'Microsoft Teams'),
#  (0.00798019807922988, 'Python'),
#  (0.0079440182579536, 'Gitlab'),
#  (0.007839554704367474, 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)'),
#  (0.007718844902358321, 'Scala'),
#  (0.0077142414925558235, 'MySQL'),
#  (0.007708605544289085, 'C'),
#  (0.007259728851216282, 'Java'),
#  (0.0071193851550693495, 'Kubernetes'),
#  (0.0069022964562476165, 'Developer, desktop or enterprise applications'),
#  (0.006785821478528725, 'Redis'),
#  (0.006758898755913144, 'Oracle'),
#  (0.006738280163800128, 'React.js'),
#  (0.006684354243678066, 'Microsoft Azure'),
#  (0.006674314159756837, 'Stack Overflow for Teams'),
#  (0.006656788189349486, 'Node.js'),
#  (0.006622818617974707, 'R'),
#  (0.006516909585226746, 'SQLite'),
#  (0.006493626618418542, 'WordPress'),
#  (0.006057730081007689, 'Academic researcher'),
#  (0.006051085876822997, 'Assembly'),
#  (0.006040192901308872, 'Product manager'),
#  (0.005887879312890769, 'Angular.js'),
#  (0.005875163019184737, 'iOS'),
#  (0.00580534107973168, 'Developer, mobile'),
#  (0.005757924337083207, 'Professional degree (JD, MD, etc.)'),
#  (0.0057296775962137085, 'Kotlin'),
#  (0.005724926837772756, 'Trello'),
#  (0.005704779312139209, 'Puppet'),
#  (0.00564756865701991, 'Developer, embedded applications or devices'),
#  (0.005562073763648105, 'Pandas'),
#  (0.005512217653807473, 'Other doctoral degree (Ph.D., Ed.D., etc.)'),
#  (0.005448076361240561, 'VBA'),
#  (0.005435469030985906, 'Engineer, site reliability'),
#  (0.0053948651876559095, '.NET'),
#  (0.005158617371997006, 'Hadoop'),
#  (0.00512241150551859, 'Cassandra'),
#  (0.005076057348753382, 'Ruby'),
#  (0.004873664238611964,
#   'Some college/university study without earning a degree'),
#  (0.004785480196554451, 'Spring'),
#  (0.004735722019606983, 'Microsoft Azure'),
#  (0.004688263091638063, 'Data or business analyst'),
#  (0.004673587409812872, 'Android'),
#  (0.004630312328520015, 'Angular'),
#  (0.004551294994306135, 'Express'),
#  (0.004521129009796427, 'MongoDB'),
#  (0.004480573749121085, 'Flask'),
#  (0.00446729949367729, 'Haskell'),
#  (0.004463613968561802, 'Scientist'),
#  (0.0044472239015735495, 'Elasticsearch'),
#  (0.00441125068152871, 'Apache Spark'),
#  (0.004258623346552965, 'Engineer, data'),
#  (0.004256557820366527, 'System administrator'),
#  (0.004239463184317781, 'Heroku'),
#  (0.004207777809995674, 'DevOps specialist'),
#  (0.004185025893301892, 'Firebase'),
#  (0.004147003373469747, 'Designer'),
#  (0.003989083769498233, 'Raspberry Pi'),
#  (0.003960571378008307, 'Perl'),
#  (0.0038903191120640197, 'Swift'),
#  (0.003677719026195087, 'Torch/PyTorch'),
#  (0.003651013110895303, 'Laravel'),
#  (0.003638970611020779, 'Chef'),
#  (0.0036200435678732253, 'Data scientist or machine learning specialist'),
#  (0.003604000937828902, 'React Native'),
#  (0.003394074484550903, 'Teraform'),
#  (0.0033028979687859056, 'TensorFlow'),
#  (0.003121606579865302, 'ASP.NET'),
#  (0.003019658314457489, 'Slack Apps and Integrations'),
#  (0.0030008417336144138, 'Vue.js'),
#  (0.0029970073161735126, 'MariaDB'),
#  (0.0028865422699761384, '.NET Core'),
#  (0.002884721501170415, 'Ruby on Rails'),
#  (0.0028192043717354233, 'Developer, QA or test'),
#  (0.00276418382095968, 'Educator'),
#  (0.0025890030264280645, 'Database administrator'),
#  (0.002489829065391654, 'Arduino'),
#  (0.0023910940277583072, 'Julia'),
#  (0.00234949744027499, 'Django'),
#  (0.002345904293321228, 'Developer, game or graphics'),
#  (0.002227959325142782, 'Couchbase'),
#  (0.002203161710732816, 'Associate degree (A.A., A.S., etc.)'),
#  (0.002118528373785856, 'Gatsby'),
#  (0.0021042255872953837, 'ASP.NET Core'),
#  (0.001857989724874359, 'Ansible'),
#  (0.0017938326763730598, 'Unity 3D'),
#  (0.0017719281471474816, 'Keras'),
#  (0.0017128653938750051, 'Marketing or sales professional'),
#  (0.0016619533199344816,
#   'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'),
#  (0.0015083706281139133, 'Dart'),
#  (0.0011290687863641424, 'IBM Cloud or Watson'),
#  (0.001043713125619804, 'IBM DB2'),
#  (0.0010423876262768731, 'Unreal Engine'),
#  (0.0009945149878150725, 'Xamarin'),
#  (0.0009877893030356313, 'Cordova'),
#  (0.0009411509583582118, 'Drupal'),
#  (0.0004544337547644389, 'Symfony'),
#  (0.0003783936146142565, 'Flutter'),
#  (0.00019510985430084112, 'I never completed any formal education'),
#  (2.4697869832034963e-05, 'Primary/elementary school')]

# %%
country_list=X['Country'].unique()
fig, ax=plt.subplots(1, 2)
for idx, each_country in enumerate(country_list): 
    X[X['Country']==each_country]['ConvertedComp'].hist(ax=ax[idx%2])
    ax[idx%2].set_title(each_country)
    if (idx%2)!=0:
        plt.show()
        fig, ax=plt.subplots(1, 2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-4acf74b04875> in <module>
# ----> 1 country_list=X['Country'].unique()
#       2 fig, ax=plt.subplots(1, 2)
#       3 for idx, each_country in enumerate(country_list):
#       4     X[X['Country']==each_country]['ConvertedComp'].hist(ax=ax[idx%2])
#       5     ax[idx%2].set_title(each_country)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'

# %%
X.plot('Age', 'ConvertedComp', kind='scatter')

# %%
len(X)
# Out:
# 64461

# %%
X['ConvertedComp'].hist()

# %%
input_ary=X.dropna().drop('ConvertedComp', axis=1)
y=X.dropna()['ConvertedComp']
print(input_ary.shape)
sorted(input_ary.columns)
# Out:
# (5983, 4)
# ['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(input_ary, y)
rfr=RandomForestRegressor()
rfr.fit(X_train, y_train)
print(f'Train Score: {rfr.score(X_train, y_train)}')
print(f'Test Score: {rfr.score(X_test, y_test)}')
# Out:
# Train Score: 0.2519919997557962
# Test Score: 0.007281143831855741
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
sorted(list(zip(rfr.feature_importances_, input_ary.columns)), reverse=True)
# Out:
# [(0.6461945257021073, 'YearsCodePro'), (0.3538054742978926, 'YearsCode')]

# %%
y_test.hist()

# %%
y_train.hist()

# %%
sample=random.randint(0, len(input_ary))
print(f'Sample {sample}: Predicted {rfr.predict([input_ary.iloc[sample]])} vs. Actual {y.iloc[sample]}')
# Out:
# Sample 1895: Predicted [147200.] vs. Actual 115000.0

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# scaler=StandardScaler()
# scaler.fit(X_train)
# X_train=scaler.transform(X_train)
# X_test=scaler.transform(X_test)

lr=LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# lr.fit(input_ary, y)
# lr.score(input_ary, y)
# Out:
# 0.10458292668266389

# %%
pd.concat([input_ary, y], axis=1).corr()
# Out:
#                                      Age  Age1stCode  YearsCode  YearsCodePro  \
# Age                             1.000000    0.024958   0.804631      0.848196
# Age1stCode                      0.024958    1.000000  -0.339182     -0.165010
# YearsCode                       0.804631   -0.339182   1.000000      0.889315
# YearsCodePro                    0.848196   -0.165010   0.889315      1.000000
# I am a developer by profession -0.087827   -0.015597  -0.034693     -0.000252
# ...                                  ...         ...        ...           ...
# Viet Nam                             NaN         NaN        NaN           NaN
# Yemen                                NaN         NaN        NaN           NaN
# Zambia                               NaN         NaN        NaN           NaN
# Zimbabwe                             NaN         NaN        NaN           NaN
# ConvertedComp                   0.238432   -0.155800   0.310869      0.318865
#
#                                 I am a developer by profession  \
# Age                                                  -0.087827
# Age1stCode                                           -0.015597
# YearsCode                                            -0.034693
# YearsCodePro                                         -0.000252
# I am a developer by profession                        1.000000
# ...                                                        ...
# Viet Nam                                                   NaN
# Yemen                                                      NaN
# Zambia                                                     NaN
# Zimbabwe                                                   NaN
# ConvertedComp                                         0.027845
#
#                                 I am a student who is learning to code  \
# Age                                                                NaN
# Age1stCode                                                         NaN
# YearsCode                                                          NaN
# YearsCodePro                                                       NaN
# I am a developer by profession                                     NaN
# ...                                                                ...
# Viet Nam                                                           NaN
# Yemen                                                              NaN
# Zambia                                                             NaN
# Zimbabwe                                                           NaN
# ConvertedComp                                                      NaN
#
#                                 I am not primarily a developer, but I write code sometimes as part of my work  \
# Age                                                                      0.087827
# Age1stCode                                                               0.015597
# YearsCode                                                                0.034693
# YearsCodePro                                                             0.000252
# I am a developer by profession                                          -1.000000
# ...                                                                           ...
# Viet Nam                                                                      NaN
# Yemen                                                                         NaN
# Zambia                                                                        NaN
# Zimbabwe                                                                      NaN
# ConvertedComp                                                           -0.027845
#
#                                 I code primarily as a hobby  \
# Age                                                     NaN
# Age1stCode                                              NaN
# YearsCode                                               NaN
# YearsCodePro                                            NaN
# I am a developer by profession                          NaN
# ...                                                     ...
# Viet Nam                                                NaN
# Yemen                                                   NaN
# Zambia                                                  NaN
# Zimbabwe                                                NaN
# ConvertedComp                                           NaN
#
#                                 I used to be a developer by profession, but no longer am  \
# Age                                                                           NaN
# Age1stCode                                                                    NaN
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# I am a developer by profession                                                NaN
# ...                                                                           ...
# Viet Nam                                                                      NaN
# Yemen                                                                         NaN
# Zambia                                                                        NaN
# Zimbabwe                                                                      NaN
# ConvertedComp                                                                 NaN
#
#                                 Associate degree (A.A., A.S., etc.)  ...  \
# Age                                                        0.022553  ...
# Age1stCode                                                 0.026562  ...
# YearsCode                                                 -0.005927  ...
# YearsCodePro                                               0.003058  ...
# I am a developer by profession                             0.001171  ...
# ...                                                             ...  ...
# Viet Nam                                                        NaN  ...
# Yemen                                                           NaN  ...
# Zambia                                                          NaN  ...
# Zimbabwe                                                        NaN  ...
# ConvertedComp                                             -0.083763  ...
#
#                                 United Republic of Tanzania  United States  \
# Age                                                     NaN            NaN
# Age1stCode                                              NaN            NaN
# YearsCode                                               NaN            NaN
# YearsCodePro                                            NaN            NaN
# I am a developer by profession                          NaN            NaN
# ...                                                     ...            ...
# Viet Nam                                                NaN            NaN
# Yemen                                                   NaN            NaN
# Zambia                                                  NaN            NaN
# Zimbabwe                                                NaN            NaN
# ConvertedComp                                           NaN            NaN
#
#                                 Uruguay  Uzbekistan  \
# Age                                 NaN         NaN
# Age1stCode                          NaN         NaN
# YearsCode                           NaN         NaN
# YearsCodePro                        NaN         NaN
# I am a developer by profession      NaN         NaN
# ...                                 ...         ...
# Viet Nam                            NaN         NaN
# Yemen                               NaN         NaN
# Zambia                              NaN         NaN
# Zimbabwe                            NaN         NaN
# ConvertedComp                       NaN         NaN
#
#                                 Venezuela, Bolivarian Republic of...  \
# Age                                                              NaN
# Age1stCode                                                       NaN
# YearsCode                                                        NaN
# YearsCodePro                                                     NaN
# I am a developer by profession                                   NaN
# ...                                                              ...
# Viet Nam                                                         NaN
# Yemen                                                            NaN
# Zambia                                                           NaN
# Zimbabwe                                                         NaN
# ConvertedComp                                                    NaN
#
#                                 Viet Nam  Yemen  Zambia  Zimbabwe  \
# Age                                  NaN    NaN     NaN       NaN
# Age1stCode                           NaN    NaN     NaN       NaN
# YearsCode                            NaN    NaN     NaN       NaN
# YearsCodePro                         NaN    NaN     NaN       NaN
# I am a developer by profession       NaN    NaN     NaN       NaN
# ...                                  ...    ...     ...       ...
# Viet Nam                             NaN    NaN     NaN       NaN
# Yemen                                NaN    NaN     NaN       NaN
# Zambia                               NaN    NaN     NaN       NaN
# Zimbabwe                             NaN    NaN     NaN       NaN
# ConvertedComp                        NaN    NaN     NaN       NaN
#
#                                 ConvertedComp
# Age                                  0.238432
# Age1stCode                          -0.155800
# YearsCode                            0.310869
# YearsCodePro                         0.318865
# I am a developer by profession       0.027845
# ...                                       ...
# Viet Nam                                  NaN
# Yemen                                     NaN
# Zambia                                    NaN
# Zimbabwe                                  NaN
# ConvertedComp                        1.000000
#
# [214 rows x 214 columns]

# %%
# sorted(list(zip(lr.feature_importances_, input_ary.columns)), reverse=True)

# %%
sample=random.randint(0, len(input_ary))
print(f'Sample {sample}: Predicted {lr.predict([input_ary.iloc[sample]])} vs. Actual {y.iloc[sample]}')
# Out:
# Sample 20939: Predicted [118998.] vs. Actual 125000.0

# %%
y.hist()

# %%
sorted(list(zip(lr.coef_, input_ary.columns)), reverse=True)
# Out:
# [(2426023947109233.5, 'I am a student who is learning to code'),
#  (991503667328940.0, 'I code primarily as a hobby'),
#  (262347868603312.0, 'Bahamas'),
#  (61453302869705.805, 'Cape Verde'),
#  (34734744215985.87, 'Burundi'),
#  (16391583293851.691, 'Antigua and Barbuda'),
#  (5609401917969.099, 'Liechtenstein'),
#  (4662689295839.5625, 'Gambia'),
#  (4458970706911.093, 'Libyan Arab Jamahiriya'),
#  (2961356137186.703, 'Fiji'),
#  (2141773325017.5042, 'Gabon'),
#  (1895532133566.1768, 'Namibia'),
#  (1799020161363.7231, 'Haiti'),
#  (1461234517251.7798, 'Nauru'),
#  (1301073169372.9092, 'Mozambique'),
#  (1057935901761.39, 'Marshall Islands'),
#  (983958561692.1804, 'Kiribati'),
#  (626715583880.5612, 'Mauritania'),
#  (273428562908.77737, 'Maldives'),
#  (269915350742.3785, 'Papua New Guinea'),
#  (167522928663.7578, 'Solomon Islands'),
#  (141124257780.9145, 'Saint Lucia'),
#  (14951.126206144287, 'I never completed any formal education'),
#  (13407.59375, 'Engineering manager'),
#  (12287.200543561921, 'Other doctoral degree (Ph.D., Ed.D., etc.)'),
#  (11971.089734407851, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'),
#  (8316.375, 'Scala'),
#  (8047.368564276712, 'Primary/elementary school'),
#  (7758.462605197914, 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)'),
#  (7210.25, 'Go'),
#  (5799.5625, 'Ruby'),
#  (5366.5, 'Engineer, site reliability'),
#  (5074.145533690527,
#   'A business discipline (such as accounting, finance, marketing, etc.)'),
#  (5051.5355712237815,
#   'A health science (such as nursing, pharmacy, radiology, etc.)'),
#  (4987.380030418368,
#   'A social science (such as anthropology, psychology, political science, etc.)'),
#  (4766.546397173487, 'Some college/university study without earning a degree'),
#  (4446.9375, 'Objective-C'),
#  (4411.25, 'TypeScript'),
#  (4305.21875, 'Senior executive/VP'),
#  (4277.5, 'Data scientist or machine learning specialist'),
#  (3956.6890384217345,
#   'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'),
#  (3646.0194718586313, 'Mathematics or statistics'),
#  (3461.15625, 'DevOps specialist'),
#  (3187.022970424954,
#   'Another engineering discipline (such as civil, electrical, mechanical, etc.)'),
#  (3179.7973120643346, 'Professional degree (JD, MD, etc.)'),
#  (3023.9551976552466,
#   'Information systems, information technology, or system administration'),
#  (3002.238998719293,
#   'A natural science (such as biology, chemistry, physics, etc.)'),
#  (2980.282099887949,
#   'Fine arts or performing arts (such as graphic design, music, studio art, etc.)'),
#  (2684.9296437575103,
#   'Computer science, computer engineering, or software engineering'),
#  (2409.625, 'Engineer, data'),
#  (2231.5, 'Bash/Shell/PowerShell'),
#  (2165.75, 'Product manager'),
#  (1993.6482416540057,
#   'A humanities discipline (such as literature, history, philosophy, etc.)'),
#  (1934.0, 'Developer, back-end'),
#  (1814.4921875, 'Rust'),
#  (1563.125, 'Man'),
#  (1344.294298447734, 'YearsCodePro'),
#  (1021.0, 'Java'),
#  (976.0, 'JavaScript'),
#  (858.75, 'Developer, mobile'),
#  (832.0, 'Developer, full-stack'),
#  (697.125, 'Swift'),
#  (597.4902392717086, 'I never declared a major'),
#  (587.75, 'Kotlin'),
#  (561.8439342861748, 'Web development or web design'),
#  (561.25, 'Python'),
#  (159.51453910815803, 'Age'),
#  (6.961487884039116, 'YearsCode'),
#  (-212.375, 'Educator'),
#  (-318.8563393865227, 'Age1stCode'),
#  (-339.5625, 'Marketing or sales professional'),
#  (-588.8358891169955, 'Associate degree (A.A., A.S., etc.)'),
#  (-614.78125, 'Assembly'),
#  (-644.75, 'C++'),
#  (-754.765625, 'Non-binary, genderqueer, or gender non-conforming'),
#  (-951.5, 'C'),
#  (-959.3125, 'Perl'),
#  (-1044.375, 'Developer, embedded applications or devices'),
#  (-1066.0, 'Developer, desktop or enterprise applications'),
#  (-1192.46875, 'Developer, game or graphics'),
#  (-1556.75, 'Developer, front-end'),
#  (-1664.09375, 'SQL'),
#  (-1896.90625, 'R'),
#  (-1974.875, 'Woman'),
#  (-2191.921875, 'Developer, QA or test'),
#  (-2491.53125, 'Haskell'),
#  (-2499.25, 'C#'),
#  (-2712.75, 'HTML/CSS'),
#  (-2911.40625, 'Data or business analyst'),
#  (-3096.046875, 'Dart'),
#  (-3234.0, 'Database administrator'),
#  (-3334.9375, 'VBA'),
#  (-3594.9375, 'Scientist'),
#  (-3753.109375, 'Julia'),
#  (-4677.375, 'Designer'),
#  (-5227.75, 'PHP'),
#  (-5314.09375, 'System administrator'),
#  (-6020.9375, 'Academic researcher'),
#  (-47576009200.63533, 'Micronesia, Federated States of...'),
#  (-132432197072.20187, 'Saint Vincent and the Grenadines'),
#  (-308160468764.875, 'Tajikistan'),
#  (-774140288749.2764, 'Sierra Leone'),
#  (-781857502779.2031, 'Timor-Leste'),
#  (-1651937595330.2822, 'Mali'),
#  (-2989792206994.9272, 'Mongolia'),
#  (-3651979556428.363, 'North Korea'),
#  (-5896465852656.994, 'Eritrea'),
#  (-6198137451078.858, 'Grenada'),
#  (-8867385209696.305, 'Belize'),
#  (-9157941095285.326, 'Chad'),
#  (-10035587877697.621, 'Djibouti'),
#  (-40989200445230.01, 'Congo, Republic of the...'),
#  (-66475739635171.79, 'Brunei Darussalam'),
#  (-76549891639761.75, 'Burkina Faso'),
#  (-81492367625960.6, 'Andorra'),
#  (-81492367629877.75, 'United States'),
#  (-81492367641364.88, 'Israel'),
#  (-81492367642595.03, 'Switzerland'),
#  (-81492367651146.31, "Lao People's Democratic Republic"),
#  (-81492367654129.48, 'Denmark'),
#  (-81492367655196.5, 'Nomadic'),
#  (-81492367658914.5, 'Iceland'),
#  (-81492367660367.88, 'Norway'),
#  (-81492367660848.28, 'Ireland'),
#  (-81492367661449.47, 'Australia'),
#  (-81492367662125.69, 'Luxembourg'),
#  (-81492367662273.6, 'Hong Kong (S.A.R.)'),
#  (-81492367664962.9, 'Canada'),
#  (-81492367667937.06, 'United Kingdom'),
#  (-81492367668480.75, 'Benin'),
#  (-81492367672145.9, 'New Zealand'),
#  (-81492367672731.62, 'Germany'),
#  (-81492367672750.42, 'Singapore'),
#  (-81492367673039.95, 'Saudi Arabia'),
#  (-81492367674548.9, 'Netherlands'),
#  (-81492367678217.14, 'Belgium'),
#  (-81492367680017.42, 'Japan'),
#  (-81492367680230.12, 'Costa Rica'),
#  (-81492367680230.77, 'Turkmenistan'),
#  (-81492367680476.62, 'Qatar'),
#  (-81492367681112.19, 'Austria'),
#  (-81492367681693.25, 'Sweden'),
#  (-81492367682250.7, 'Finland'),
#  (-81492367683317.5, 'Bahrain'),
#  (-81492367683731.22, 'Zambia'),
#  (-81492367683832.38, 'Oman'),
#  (-81492367683872.98, 'Zimbabwe'),
#  (-81492367684789.23, 'United Republic of Tanzania'),
#  (-81492367685966.3, 'Malawi'),
#  (-81492367686246.19, 'Republic of Korea'),
#  (-81492367686973.56, 'South Korea'),
#  (-81492367687066.23, 'Kuwait'),
#  (-81492367687545.1, 'Lithuania'),
#  (-81492367687922.22, 'Malta'),
#  (-81492367688215.73, 'France'),
#  (-81492367688288.2, 'Cyprus'),
#  (-81492367689503.84, 'Isle of Man'),
#  (-81492367690651.16, 'South Africa'),
#  (-81492367691227.38, 'Paraguay'),
#  (-81492367691514.7, 'Swaziland'),
#  (-81492367691562.05, 'Rwanda'),
#  (-81492367691676.05, 'San Marino'),
#  (-81492367691848.66, 'China'),
#  (-81492367692581.34, 'United Arab Emirates'),
#  (-81492367693344.31, 'Taiwan'),
#  (-81492367693383.1, 'Estonia'),
#  (-81492367693435.25, 'Slovenia'),
#  (-81492367693564.06, 'Uruguay'),
#  (-81492367693877.19, 'Montenegro'),
#  (-81492367693949.52, 'Spain'),
#  (-81492367694448.16, 'Czech Republic'),
#  (-81492367694915.06, 'Panama'),
#  (-81492367695372.94, 'Romania'),
#  (-81492367696297.88, 'Albania'),
#  (-81492367696713.7, 'Poland'),
#  (-81492367696964.75, 'Italy'),
#  (-81492367697527.38, 'Yemen'),
#  (-81492367697593.4, 'Latvia'),
#  (-81492367698409.1, 'Bosnia and Herzegovina'),
#  (-81492367698549.7, 'Slovakia'),
#  (-81492367698759.25, 'Thailand'),
#  (-81492367699426.8, 'Bulgaria'),
#  (-81492367699823.12, 'Ukraine'),
#  (-81492367700096.75, 'Lebanon'),
#  (-81492367700145.34, 'Somalia'),
#  (-81492367700394.16, 'Trinidad and Tobago'),
#  (-81492367701391.92, 'Barbados'),
#  (-81492367701765.06, 'Chile'),
#  (-81492367701994.84, 'Jamaica'),
#  (-81492367702208.42, 'Greece'),
#  (-81492367702598.38, 'Belarus'),
#  (-81492367702640.1, 'Portugal'),
#  (-81492367702979.72, 'Croatia'),
#  (-81492367703484.97, 'Guatemala'),
#  (-81492367703909.23, 'Dominican Republic'),
#  (-81492367703943.36, 'Nicaragua'),
#  (-81492367704325.23, 'Botswana'),
#  (-81492367704767.06, 'Mexico'),
#  (-81492367704997.22, 'Jordan'),
#  (-81492367705314.66, "Côte d'Ivoire"),
#  (-81492367705431.97, 'Morocco'),
#  (-81492367705521.69, 'Hungary'),
#  (-81492367705882.67, 'Guinea'),
#  (-81492367706013.22, 'Serbia'),
#  (-81492367706101.5, 'The former Yugoslav Republic of Macedonia'),
#  (-81492367706318.72, 'Guyana'),
#  (-81492367706569.23, 'Monaco'),
#  (-81492367706628.84, 'Democratic Republic of the Congo'),
#  (-81492367706845.03, 'Russian Federation'),
#  (-81492367707469.28, 'Iraq'),
#  (-81492367708021.44, 'Afghanistan'),
#  (-81492367708070.22, 'Kosovo'),
#  (-81492367708334.56, 'Armenia'),
#  (-81492367708381.95, 'Colombia'),
#  (-81492367708474.3, 'Turkey'),
#  (-81492367708621.61, 'Malaysia'),
#  (-81492367708675.72, 'Peru'),
#  (-81492367708764.11, 'Egypt'),
#  (-81492367708773.6, 'Georgia'),
#  (-81492367709466.03, 'Uganda'),
#  (-81492367709477.39, 'Kenya'),
#  (-81492367710036.34, 'Senegal'),
#  (-81492367710488.25, 'Brazil'),
#  (-81492367710704.06, 'Philippines'),
#  (-81492367710732.56, 'Viet Nam'),
#  (-81492367710779.94, 'Mauritius'),
#  (-81492367711207.03, 'Ghana'),
#  (-81492367711332.53, 'Honduras'),
#  (-81492367711508.84, 'Nigeria'),
#  (-81492367711787.86, 'Bolivia'),
#  (-81492367712274.3, 'Argentina'),
#  (-81492367712314.4, 'India'),
#  (-81492367712477.39, 'Iran'),
#  (-81492367712689.28, 'Ethiopia'),
#  (-81492367712789.28, 'Cuba'),
#  (-81492367712970.72, 'Ecuador'),
#  (-81492367713018.61, 'Tunisia'),
#  (-81492367713152.69, 'Republic of Moldova'),
#  (-81492367713279.12, 'Pakistan'),
#  (-81492367714357.94, 'El Salvador'),
#  (-81492367714394.83, 'Niger'),
#  (-81492367714810.53, 'Indonesia'),
#  (-81492367714850.61, 'Angola'),
#  (-81492367714909.38, 'Madagascar'),
#  (-81492367715301.56, 'Azerbaijan'),
#  (-81492367715443.33, 'Nepal'),
#  (-81492367715779.1, 'Algeria'),
#  (-81492367715800.02, 'Bangladesh'),
#  (-81492367716669.34, 'Sri Lanka'),
#  (-81492367716838.12, 'Kyrgyzstan'),
#  (-81492367717020.56, 'Kazakhstan'),
#  (-81492367718137.9, 'Uzbekistan'),
#  (-81492367718861.33, 'Myanmar'),
#  (-81492367719244.56, 'Sudan'),
#  (-81492367720369.28, 'Venezuela, Bolivarian Republic of...'),
#  (-81492367720699.69, 'Syrian Arab Republic'),
#  (-81492367722249.8, 'Cameroon'),
#  (-81492367723618.5, 'Lesotho'),
#  (-81492367727878.67, 'Cambodia'),
#  (-81492367729624.36, 'Togo'),
#  (-140333660448538.98, 'Bhutan'),
#  (-2277903628093340.0,
#   'I used to be a developer by profession, but no longer am'),
#  (-4961443747809523.0, 'I am a developer by profession'),
#  (-4961443747811219.0,
#   'I am not primarily a developer, but I write code sometimes as part of my work')]

# %%
y_test.max()
# Out:
# 200000.0

# %%
import numpy as np
np.max(lr.predict(X_test))
# Out:
# 343840236338071.0

# %%
lr.intercept_
# Out:
# 5042936115521417.0

# %%
plt.scatter(y_test, lr.predict(X_test))

# %%
plt.hist(lr.predict(X_test))
# Out:
# (array([2.00e+00, 6.76e+03, 0.00e+00, 6.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00]),
#  array([-5.88412927e+13, -1.85731398e+13,  2.16950131e+13,  6.19631660e+13,
#          1.02231319e+14,  1.42499472e+14,  1.82767625e+14,  2.23035778e+14,
#          2.63303931e+14,  3.03572083e+14,  3.43840236e+14]),
#  <a list of 10 Patch objects>)

# %%
print(categoricals)
print(numericals)
print(multi_options)
# Out:
# ['MainBranch', 'EdLevel', 'UndergradMajor', 'Country']
# ['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
# []

# %% [markdown]
# ['MainBranch', 'EdLevel', 'UndergradMajor', 'Country']
#
# ['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']
#
# []
#
# LR - -244864609971947.5
#
# RFR - 0.6037828435133481

# %%
list(input_ary.columns)
# Out:
# ['Age',
#  'Age1stCode',
#  'YearsCode',
#  'YearsCodePro',
#  'I am a developer by profession',
#  'I am a student who is learning to code',
#  'I am not primarily a developer, but I write code sometimes as part of my work',
#  'I code primarily as a hobby',
#  'I used to be a developer by profession, but no longer am',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo, Republic of the...',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  "Côte d'Ivoire",
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong (S.A.R.)',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic",
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Libyan Arab Jamahiriya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia, Federated States of...',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Nomadic',
#  'North Korea',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Republic of Korea',
#  'Republic of Moldova',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'San Marino',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'The former Yugoslav Republic of Macedonia',
#  'Timor-Leste',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United Republic of Tanzania',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela, Bolivarian Republic of...',
#  'Viet Nam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Associate degree (A.A., A.S., etc.)',
#  'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#  'I never completed any formal education',
#  'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#  'Other doctoral degree (Ph.D., Ed.D., etc.)',
#  'Primary/elementary school',
#  'Professional degree (JD, MD, etc.)',
#  'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#  'Some college/university study without earning a degree',
#  'Employed full-time',
#  'Employed part-time',
#  'Independent contractor, freelancer, or self-employed',
#  'Not employed, and not looking for work',
#  'Not employed, but looking for work',
#  'Retired',
#  'Student',
#  'BSD',
#  'Linux-based',
#  'MacOS',
#  'Windows',
#  'A business discipline (such as accounting, finance, marketing, etc.)',
#  'A health science (such as nursing, pharmacy, radiology, etc.)',
#  'A humanities discipline (such as literature, history, philosophy, etc.)',
#  'A natural science (such as biology, chemistry, physics, etc.)',
#  'A social science (such as anthropology, psychology, political science, etc.)',
#  'Another engineering discipline (such as civil, electrical, mechanical, etc.)',
#  'Computer science, computer engineering, or software engineering',
#  'Fine arts or performing arts (such as graphic design, music, studio art, etc.)',
#  'I never declared a major',
#  'Information systems, information technology, or system administration',
#  'Mathematics or statistics',
#  'Web development or web design',
#  'I am a developer by profession',
#  'I am a student who is learning to code',
#  'I am not primarily a developer, but I write code sometimes as part of my work',
#  'I code primarily as a hobby',
#  'I used to be a developer by profession, but no longer am',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo, Republic of the...',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  "Côte d'Ivoire",
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong (S.A.R.)',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic",
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Libyan Arab Jamahiriya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia, Federated States of...',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Nomadic',
#  'North Korea',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Republic of Korea',
#  'Republic of Moldova',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'San Marino',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'The former Yugoslav Republic of Macedonia',
#  'Timor-Leste',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United Republic of Tanzania',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela, Bolivarian Republic of...',
#  'Viet Nam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe',
#  'Associate degree (A.A., A.S., etc.)',
#  'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#  'I never completed any formal education',
#  'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#  'Other doctoral degree (Ph.D., Ed.D., etc.)',
#  'Primary/elementary school',
#  'Professional degree (JD, MD, etc.)',
#  'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#  'Some college/university study without earning a degree',
#  'Employed full-time',
#  'Employed part-time',
#  'Independent contractor, freelancer, or self-employed',
#  'Not employed, and not looking for work',
#  'Not employed, but looking for work',
#  'Retired',
#  'Student',
#  'BSD',
#  'Linux-based',
#  'MacOS',
#  'Windows',
#  'A business discipline (such as accounting, finance, marketing, etc.)',
#  'A health science (such as nursing, pharmacy, radiology, etc.)',
#  'A humanities discipline (such as literature, history, philosophy, etc.)',
#  'A natural science (such as biology, chemistry, physics, etc.)',
#  'A social science (such as anthropology, psychology, political science, etc.)',
#  'Another engineering discipline (such as civil, electrical, mechanical, etc.)',
#  'Computer science, computer engineering, or software engineering',
#  'Fine arts or performing arts (such as graphic design, music, studio art, etc.)',
#  'I never declared a major',
#  'Information systems, information technology, or system administration',
#  'Mathematics or statistics',
#  'Web development or web design']

# %%
categoricals={}
for col, col_type in df.dtypes.iteritems(): 
    if col_type=='O':
        categoricals[col]=df[col].nunique()
#         print(f'{col} is {col_type}')
        
categoricals
# Out:
# {'MainBranch': 5,
#  'Hobbyist': 2,
#  'Age1stCode': 63,
#  'CompFreq': 3,
#  'Country': 183,
#  'CurrencyDesc': 142,
#  'CurrencySymbol': 141,
#  'DatabaseDesireNextYear': 3193,
#  'DatabaseWorkedWith': 2808,
#  'DevType': 8269,
#  'EdLevel': 9,
#  'Employment': 7,
#  'Ethnicity': 208,
#  'Gender': 7,
#  'JobFactors': 230,
#  'JobSat': 5,
#  'JobSeek': 3,
#  'LanguageDesireNextYear': 16243,
#  'LanguageWorkedWith': 14256,
#  'MiscTechDesireNextYear': 5216,
#  'MiscTechWorkedWith': 2730,
#  'NEWCollabToolsDesireNextYear': 1277,
#  'NEWCollabToolsWorkedWith': 1153,
#  'NEWDevOps': 3,
#  'NEWDevOpsImpt': 5,
#  'NEWEdImpt': 5,
#  'NEWJobHunt': 2172,
#  'NEWJobHuntResearch': 63,
#  'NEWLearn': 4,
#  'NEWOffTopic': 3,
#  'NEWOnboardGood': 3,
#  'NEWOtherComms': 2,
#  'NEWOvertime': 5,
#  'NEWPurchaseResearch': 63,
#  'NEWPurpleLink': 4,
#  'NEWSOSites': 61,
#  'NEWStuck': 444,
#  'OpSys': 4,
#  'OrgSize': 9,
#  'PlatformDesireNextYear': 7471,
#  'PlatformWorkedWith': 6287,
#  'PurchaseWhat': 3,
#  'Sexuality': 14,
#  'SOAccount': 3,
#  'SOComm': 6,
#  'SOPartFreq': 6,
#  'SOVisitFreq': 6,
#  'SurveyEase': 3,
#  'SurveyLength': 3,
#  'Trans': 2,
#  'UndergradMajor': 12,
#  'WebframeDesireNextYear': 3986,
#  'WebframeWorkedWith': 3789,
#  'WelcomeChange': 6,
#  'YearsCode': 52,
#  'YearsCodePro': 52}

# %%
ohe.get_feature_names()
# Out:
# array(['x0_Man',
#        'x0_Man;Non-binary, genderqueer, or gender non-conforming',
#        'x0_Non-binary, genderqueer, or gender non-conforming', 'x0_Woman',
#        'x0_Woman;Man',
#        'x0_Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'x0_Woman;Non-binary, genderqueer, or gender non-conforming'],
#       dtype=object)

# %%
df['Gender'].str.get_dummies(sep=';')
# Out:
#        Man  Non-binary, genderqueer, or gender non-conforming  Woman
# 0        1                                                  0      0
# 1        0                                                  0      0
# 2        0                                                  0      0
# 3        1                                                  0      0
# 4        1                                                  0      0
# ...    ...                                                ...    ...
# 64456    0                                                  0      0
# 64457    0                                                  0      0
# 64458    0                                                  0      0
# 64459    0                                                  0      0
# 64460    0                                                  0      0
#
# [64461 rows x 3 columns]

# %%
for each_col in categoricals: 
    if categoricals[each_col]<100: 
        print(f'{each_col} options: {df[each_col].unique()}')
        print('='*20)
# Out:
# MainBranch options: ['I am a developer by profession' 'I code primarily as a hobby'
#  'I used to be a developer by profession, but no longer am'
#  'I am not primarily a developer, but I write code sometimes as part of my work'
#  'I am a student who is learning to code' nan]
# ====================
# Hobbyist options: ['Yes' 'No' nan]
# ====================
# Age1stCode options: ['13' '19' '15' '18' '16' '14' '12' '20' '42' '8' '25' '22' '30' '17' '21'
#  '10' '46' '9' '7' '11' '6' nan '31' '29' '5' 'Younger than 5 years' '28'
#  '38' '23' '27' '41' '24' '53' '26' '35' '32' '40' '33' '36' '54' '48'
#  '56' '45' '44' '34' 'Older than 85' '39' '51' '68' '50' '37' '47' '43'
#  '52' '85' '64' '55' '58' '49' '76' '72' '73' '83' '63']
# ====================
# CompFreq options: ['Monthly' nan 'Yearly' 'Weekly']
# ====================
# EdLevel options: ['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'
#  'Bachelor’s degree (B.A., B.S., B.Eng., etc.)' nan
#  'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'
#  'Professional degree (JD, MD, etc.)'
#  'Some college/university study without earning a degree'
#  'Associate degree (A.A., A.S., etc.)'
#  'Other doctoral degree (Ph.D., Ed.D., etc.)' 'Primary/elementary school'
#  'I never completed any formal education']
# ====================
# Employment options: ['Independent contractor, freelancer, or self-employed'
#  'Employed full-time' nan 'Student' 'Not employed, but looking for work'
#  'Employed part-time' 'Retired' 'Not employed, and not looking for work']
# ====================
# Gender options: ['Man' nan 'Woman' 'Man;Non-binary, genderqueer, or gender non-conforming'
#  'Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Man;Non-binary, genderqueer, or gender non-conforming' 'Woman;Man']
# ====================
# JobSat options: ['Slightly satisfied' 'Very dissatisfied' nan 'Slightly dissatisfied'
#  'Very satisfied' 'Neither satisfied nor dissatisfied']
# ====================
# JobSeek options: ['I am not interested in new job opportunities' nan
#  'I’m not actively looking, but I am open to new opportunities'
#  'I am actively looking for a job']
# ====================
# NEWDevOps options: ['No' nan 'Not sure' 'Yes']
# ====================
# NEWDevOpsImpt options: ['Somewhat important' nan 'Extremely important' 'Neutral'
#  'Not at all important' 'Not very important']
# ====================
# NEWEdImpt options: ['Fairly important' nan 'Not at all important/not necessary'
#  'Very important' 'Somewhat important' 'Critically important']
# ====================
# NEWJobHuntResearch options: [nan
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Personal network - friends or family;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Directly asking current or past employees at the company'
#  'Personal network - friends or family'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind)'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind)'
#  'Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Read other media like news articles, founder profiles, etc. about the company'
#  'Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase)'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family'
#  'Read company media, such as employee blogs or company culture videos;Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Directly asking current or past employees at the company'
#  'Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Personal network - friends or family'
#  'Read company media, such as employee blogs or company culture videos;Personal network - friends or family;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Personal network - friends or family'
#  'Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Personal network - friends or family'
#  'Read company media, such as employee blogs or company culture videos;Company reviews from third party sites (e.g. Glassdoor, Blind);Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase)'
#  'Read other media like news articles, founder profiles, etc. about the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase)'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company'
#  'Publicly available financial information (e.g. Crunchbase);Personal network - friends or family;Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company'
#  'Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Publicly available financial information (e.g. Crunchbase);Personal network - friends or family'
#  'Read company media, such as employee blogs or company culture videos;Publicly available financial information (e.g. Crunchbase);Directly asking current or past employees at the company'
#  'Company reviews from third party sites (e.g. Glassdoor, Blind);Publicly available financial information (e.g. Crunchbase);Read other media like news articles, founder profiles, etc. about the company;Directly asking current or past employees at the company'
#  'Publicly available financial information (e.g. Crunchbase)'
#  'Publicly available financial information (e.g. Crunchbase);Directly asking current or past employees at the company']
# ====================
# NEWLearn options: ['Once a year' 'Once a decade' 'Every few months' 'Once every few years'
#  nan]
# ====================
# NEWOffTopic options: ['Not sure' nan 'No' 'Yes']
# ====================
# NEWOnboardGood options: [nan 'Yes' 'No' 'Onboarding? What onboarding?']
# ====================
# NEWOtherComms options: ['No' 'Yes' nan]
# ====================
# NEWOvertime options: ['Often: 1-2 days per week or more' nan
#  'Occasionally: 1-2 days per quarter but less than monthly' 'Never'
#  'Sometimes: 1-2 days per month but less than weekly'
#  'Rarely: 1-2 days per year or less']
# ====================
# NEWPurchaseResearch options: ['Start a free trial;Ask developers I know/work with' nan
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow'
#  'Ask developers I know/work with'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow'
#  'Research companies that have advertised on sites I visit'
#  'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Visit developer communities like Stack Overflow'
#  'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit'
#  'Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit'
#  'Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Start a free trial;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Research companies that have emailed me'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit'
#  'Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Visit developer communities like Stack Overflow'
#  'Start a free trial;Ask developers I know/work with;Research companies that have emailed me'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Research companies that have emailed me'
#  'Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Research companies that have advertised on sites I visit'
#  'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Ask developers I know/work with;Research companies that have advertised on sites I visit'
#  'Start a free trial;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have emailed me'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Start a free trial;Research companies that have emailed me'
#  'Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit'
#  'Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit'
#  'Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Research companies that have emailed me'
#  'Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Ask developers I know/work with;Research companies that have emailed me'
#  'Start a free trial;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Read ratings or reviews on third party sites like G2Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me'
#  'Visit developer communities like Stack Overflow;Research companies that have emailed me'
#  'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me'
#  'Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me']
# ====================
# NEWPurpleLink options: ['Amused' nan 'Hello, old friend' 'Annoyed' 'Indifferent']
# ====================
# NEWSOSites options: ['Stack Overflow (public Q&A for anyone who codes)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  nan
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Exchange (public Q&A for a variety of topics)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)'
#  'I have never visited any of these sites'
#  'Stack Overflow Jobs (for job seekers)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)'
#  'Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)'
#  'Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)']
# ====================
# OpSys options: ['Windows' 'MacOS' 'Linux-based' nan 'BSD']
# ====================
# OrgSize options: ['2 to 9 employees' '1,000 to 4,999 employees' nan '20 to 99 employees'
#  'Just me - I am a freelancer, sole proprietor, etc.'
#  '10,000 or more employees' '100 to 499 employees' '500 to 999 employees'
#  '10 to 19 employees' '5,000 to 9,999 employees']
# ====================
# PurchaseWhat options: [nan 'I have little or no influence' 'I have a great deal of influence'
#  'I have some influence']
# ====================
# Sexuality options: ['Straight / Heterosexual' nan 'Gay or Lesbian' 'Queer'
#  'Bisexual;Straight / Heterosexual' 'Bisexual' 'Bisexual;Queer'
#  'Gay or Lesbian;Queer'
#  'Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer'
#  'Bisexual;Straight / Heterosexual;Queer' 'Bisexual;Gay or Lesbian'
#  'Straight / Heterosexual;Queer'
#  'Bisexual;Gay or Lesbian;Straight / Heterosexual'
#  'Gay or Lesbian;Straight / Heterosexual' 'Bisexual;Gay or Lesbian;Queer']
# ====================
# SOAccount options: ['No' 'Yes' nan "Not sure/can't remember"]
# ====================
# SOComm options: ['No, not at all' 'Yes, definitely' 'Yes, somewhat' 'No, not really'
#  'Neutral' nan 'Not sure']
# ====================
# SOPartFreq options: [nan 'Less than once per month or monthly'
#  'A few times per month or weekly' 'Multiple times per day'
#  'I have never participated in Q&A on Stack Overflow'
#  'A few times per week' 'Daily or almost daily']
# ====================
# SOVisitFreq options: ['Multiple times per day' 'Daily or almost daily'
#  'A few times per month or weekly' 'A few times per week'
#  'I have never visited Stack Overflow (before today)' nan
#  'Less than once per month or monthly']
# ====================
# SurveyEase options: ['Neither easy nor difficult' nan 'Easy' 'Difficult']
# ====================
# SurveyLength options: ['Appropriate in length' nan 'Too short' 'Too long']
# ====================
# Trans options: ['No' nan 'Yes']
# ====================
# UndergradMajor options: ['Computer science, computer engineering, or software engineering' nan
#  'Mathematics or statistics'
#  'Another engineering discipline (such as civil, electrical, mechanical, etc.)'
#  'A humanities discipline (such as literature, history, philosophy, etc.)'
#  'A health science (such as nursing, pharmacy, radiology, etc.)'
#  'Information systems, information technology, or system administration'
#  'Web development or web design'
#  'A natural science (such as biology, chemistry, physics, etc.)'
#  'Fine arts or performing arts (such as graphic design, music, studio art, etc.)'
#  'I never declared a major'
#  'A social science (such as anthropology, psychology, political science, etc.)'
#  'A business discipline (such as accounting, finance, marketing, etc.)']
# ====================
# WelcomeChange options: ['Just as welcome now as I felt last year'
#  'Somewhat more welcome now than last year'
#  'Somewhat less welcome now than last year' nan
#  'A lot more welcome now than last year'
#  'A lot less welcome now than last year'
#  'Not applicable - I did not use Stack Overflow last year']
# ====================
# YearsCode options: ['36' '7' '4' '15' '6' '17' '8' '10' '35' '5' '37' '19' '9' '22' '30' '23'
#  '20' '2' 'Less than 1 year' '3' '13' '25' '16' '43' '11' '38' '33' nan
#  '24' '21' '12' '40' '27' '50' '46' '14' '18' '28' '32' '44' '26' '42'
#  '31' '34' '29' '1' '39' '41' '45' 'More than 50 years' '47' '49' '48']
# ====================
# YearsCodePro options: ['27' '4' nan '8' '13' '2' '7' '20' '1' '23' '3' '12' '17' '18' '10' '14'
#  '29' '6' '28' '9' '15' '11' '16' '25' 'Less than 1 year' '5' '21' '19'
#  '35' '24' '32' '22' '30' '38' '26' '40' '33' '31' 'More than 50 years'
#  '34' '36' '39' '37' '41' '45' '47' '42' '46' '50' '43' '44' '48' '49']
# ====================

# %%
comp_cols=['CompFreq','CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc','CurrencySymbol']
comp_df=df[comp_cols].dropna()
comp_df[comp_df['CompFreq']=='Weekly']
# Out:
#       CompFreq     CompTotal  ConvertedComp         Country  \
# 85      Weekly  2.000000e+03       108100.0          France
# 121     Weekly  1.200000e+05      2000000.0   United States
# 132     Weekly  3.250000e+03       210050.0  United Kingdom
# 173     Weekly  7.600000e+02        41100.0     Netherlands
# 191     Weekly  1.200000e+05      2000000.0   United States
# ...        ...           ...            ...             ...
# 63762   Weekly  1.600000e+03        80000.0   United States
# 63925   Weekly  8.740000e+09      1000000.0     Afghanistan
# 63993   Weekly  5.521171e+09      1000000.0     Afghanistan
# 64035   Weekly  6.600000e+04      2000000.0   United States
# 64129   Weekly  3.000000e+03       150000.0   United States
#
#                CurrencyDesc CurrencySymbol
# 85            European Euro            EUR
# 121    United States dollar            USD
# 132          Pound sterling            GBP
# 173           European Euro            EUR
# 191    United States dollar            USD
# ...                     ...            ...
# 63762  United States dollar            USD
# 63925        Afghan afghani            AFN
# 63993        Afghan afghani            AFN
# 64035  United States dollar            USD
# 64129  United States dollar            USD
#
# [969 rows x 6 columns]

# %%
# comp_df[comp_df['ConvertedComp']<500000]['ConvertedComp'].hist()
# comp_df[comp_df['ConvertedComp']<500000]['ConvertedComp'].value_counts(bins=10)
comp_df['ConvertedComp'].hist()
comp_df['ConvertedComp'].value_counts(bins=20)
# Out:
# (-2000.001, 100000.0]     26847
# (100000.0, 200000.0]       5603
# (200000.0, 300000.0]        686
# (900000.0, 1000000.0]       338
# (1900000.0, 2000000.0]      265
# (300000.0, 400000.0]        235
# (400000.0, 500000.0]        159
# (500000.0, 600000.0]        154
# (600000.0, 700000.0]        133
# (700000.0, 800000.0]        110
# (800000.0, 900000.0]         93
# (1400000.0, 1500000.0]       22
# (1100000.0, 1200000.0]       22
# (1000000.0, 1100000.0]       21
# (1200000.0, 1300000.0]       17
# (1700000.0, 1800000.0]       14
# (1300000.0, 1400000.0]       13
# (1600000.0, 1700000.0]       13
# (1500000.0, 1600000.0]        6
# (1800000.0, 1900000.0]        5
# Name: ConvertedComp, dtype: int64

# %%
currency_api_url='https://api.exchangeratesapi.io/latest?base=USD'
response=requests.get(currency_api_url)
currency_conv=response.json()['rates']
currency_conv
# Out:
# {'CAD': 1.2857142857,
#  'HKD': 7.7506373879,
#  'ISK': 125.0925240563,
#  'PHP': 48.0549387285,
#  'DKK': 6.1213093182,
#  'HUF': 294.9008964553,
#  'CZK': 21.8093593223,
#  'GBP': 0.7425117197,
#  'RON': 4.0073196809,
#  'SEK': 8.4363845711,
#  'IDR': 14164.2980508265,
#  'INR': 73.7523645037,
#  'BRL': 5.1615264413,
#  'RUB': 74.0750884119,
#  'HRK': 6.2024015133,
#  'JPY': 103.9888148696,
#  'THB': 30.1603750308,
#  'CHF': 0.8900402994,
#  'EUR': 0.8224360556,
#  'MYR': 4.0600378321,
#  'BGN': 1.6085204375,
#  'TRY': 7.7832058557,
#  'CNY': 6.5318693972,
#  'NOK': 8.7670038654,
#  'NZD': 1.4190311703,
#  'ZAR': 15.1882556131,
#  'USD': 1.0,
#  'MXN': 19.828193108,
#  'SGD': 1.3328398717,
#  'AUD': 1.3477259643,
#  'ILS': 3.2667160128,
#  'KRW': 1086.109055021,
#  'PLN': 3.6819639773}

# %%
#df['Comp_USD']=
df.dropna()
df.apply(lambda x: x['CompTotal']/currency_conv['CurrencySymbol'])# if x['CurrencySymbol'] != 'USD')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-8a21a6c3f8bf> in <module>
#       1 #df['Comp_USD']=
# ----> 2 df.apply(lambda x: x['CompTotal']/currency_conv['CurrencySymbol'])# if x['CurrencySymbol'] != 'USD')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-37-8a21a6c3f8bf> in <lambda>(x)
#       1 #df['Comp_USD']=
# ----> 2 df.apply(lambda x: x['CompTotal']/currency_conv['CurrencySymbol'])# if x['CurrencySymbol'] != 'USD')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ('CompTotal', 'occurred at index Respondent')
